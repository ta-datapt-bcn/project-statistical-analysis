# %% [markdown]
# # Data extraction

# %% [markdown]
# **Preface:**
#
# We want to analyze the most popular cycling routes for every mountain pass and port in continental Spain. To achieve this we have scrapped the website *Wikiloc* for the best routes as well as downloaded all the corresponding gpx files.
#
# This lengthy process is documented in this repo:
#
# https://github.com/x-esteban/PR_Final
#
# To obtain the necessary data from our gpx files we'll need to parse them. For this purpose we'll be using a great library called *Gpxpy*.

# %% [markdown]
# **What are our initial questions?**
#
# Our goal is to analyze the most popular routes for every province and answer two questions:
#
# 1. Do cyclists from different areas prefer different kinds of routes?
# 2. Are the routes in northern Spain more hilly than the ones in the southern regions?

# %% [markdown]
# ## 1. Importing our dataframe of all routes

# %%
import pandas as pd

# %%
#We begin by importing our dataframe containing all routes.

df = pd.read_csv('df.csv')

# %%
#The column 'alpha_name' contains the name of the corresponding gpx file. 

df.head()
# Out:
#      ubicacion                                             nombre  trailrank  \
# 0  Pico Veleta    Día 1/2 - Sierra Nevada - Granada - Pico Veleta         64
# 1  Pico Veleta  Pinos Genil. Güejar Sierra. Hazas Llanas. Prad...         54
# 2  Pico Veleta                              granada - pico veleta         41
# 3  Pico Veleta  Subida al pico veleta y al radiotelescospio de...         34
# 4  Pico Veleta  Pico Veleta por el Monachil-el Purche-Sierra N...         32
#
#    distancia desnivel   dificultad  \
# 0  108,78 km  2.914 m     Moderado
# 1   83,61 km  2.563 m  Muy difícil
# 2   85,89 km  2.785 m     Moderado
# 3   32,42 km  1.199 m  Muy difícil
# 4  101,77 km  3.234 m      Difícil
#
#                                                  url  \
# 0  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...
# 1  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...
# 2  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 3  https://es.wikiloc.com/rutas-ciclismo/subida-a...
# 4  https://es.wikiloc.com/rutas-ciclismo/pico-vel...
#
#                                               photo1  \
# 0  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...
# 1  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...
# 2  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 3  https://es.wikiloc.com/rutas-ciclismo/subida-a...
# 4  https://es.wikiloc.com/rutas-ciclismo/pico-vel...
#
#                                               photo2  \
# 0  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...
# 1  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...
# 2  https://es.wikiloc.com/rutas-ciclismo/granada-...
# 3  https://es.wikiloc.com/rutas-ciclismo/subida-a...
# 4  https://es.wikiloc.com/rutas-ciclismo/pico-vel...
#
#                                               photo3            alpha_name
# 0  https://es.wikiloc.com/rutas-ciclismo/dia-1-2-...  Día12SierraNevadaGra
# 1  https://es.wikiloc.com/rutas-ciclismo/pinos-ge...  PinosGenilGüejarSier
# 2  https://es.wikiloc.com/rutas-ciclismo/granada-...     granadapicoveleta
# 3  https://es.wikiloc.com/rutas-ciclismo/subida-a...  Subidaalpicoveletaya
# 4  https://es.wikiloc.com/rutas-ciclismo/pico-vel...  PicoVeletaporelMonac

# %% [markdown]
# ## 2. Parsing our gpx files

# %% [markdown]
# To obtain meaningful conclusions we must parse the gpx files so that we will be able to add their contents to our dataframe.
#
# We also suspect that some routes aren't even in Spanish soil, so we'll use the parsed coordinates to obtain their exact location.
#
# Let's start by defining a function that will parse a given gpx file and return a list with all necessary data. We're opting for lists instead of dataframes or dictionaries because they're way less memory intensive and require less resources.

# %%
#Importing necessary libraries.

import gpxpy
import gpxpy.gpx
import time

# %%
#Parsing our gpx file, for this example we're using 'Madrona.gpx'.

gpx = gpxpy.parse(open('Madrona.gpx'))

# %%
#Appending each point with their parameters to a list.

data = []

track = gpx.tracks[0]
segment = track.segments[0]
segment_length = segment.length_3d()
for point_idx, point in enumerate(segment.points): #Iterating through all the points in our gpx file.
    data.append([point.longitude, #Getting all parameters from each point.
                 point.latitude,
                 point.elevation, 
                 point.time, 
                 (segment.get_speed(point_idx))*3.6]) #Speed converted from m/s to km/h.

# %%
data
# Out:
# [[1.558717,
#   41.973759,
#   735.147,
#   datetime.datetime(2019, 6, 2, 8, 54, 33, tzinfo=SimpleTZ("Z")),
#   0.4286373026700454],
#  [1.558657,
#   41.973774,
#   735.129,
#   datetime.datetime(2019, 6, 2, 8, 55, 17, tzinfo=SimpleTZ("Z")),
#   8.420524427220105],
#  [1.558573,
#   41.973721,
#   735.121,
#   datetime.datetime(2019, 6, 2, 8, 55, 19, tzinfo=SimpleTZ("Z")),
#   16.584041543356516],
#  [1.558486,
#   41.973668,
#   735.108,
#   datetime.datetime(2019, 6, 2, 8, 55, 21, tzinfo=SimpleTZ("Z")),
#   22.546021272466607],
#  [1.558335,
#   41.973582,
#   735.137,
#   datetime.datetime(2019, 6, 2, 8, 55, 23, tzinfo=SimpleTZ("Z")),
#   24.71373683821654],
#  [1.558272,
#   41.973558,
#   735.111,
#   datetime.datetime(2019, 6, 2, 8, 55, 24, tzinfo=SimpleTZ("Z")),
#   21.29445493993982],
#  [1.558202,
#   41.973545,
#   735.175,
#   datetime.datetime(2019, 6, 2, 8, 55, 25, tzinfo=SimpleTZ("Z")),
#   21.640317990236746],
#  [1.558129,
#   41.973548,
#   735.187,
#   datetime.datetime(2019, 6, 2, 8, 55, 26, tzinfo=SimpleTZ("Z")),
#   22.471268817743884],
#  [1.558061,
#   41.973576,
#   735.19,
#   datetime.datetime(2019, 6, 2, 8, 55, 27, tzinfo=SimpleTZ("Z")),
#   23.57327913566868],
#  [1.558005,
#   41.973619,
#   735.133,
#   datetime.datetime(2019, 6, 2, 8, 55, 28, tzinfo=SimpleTZ("Z")),
#   24.56712614793315],
#  [1.557954,
#   41.973669,
#   735.156,
#   datetime.datetime(2019, 6, 2, 8, 55, 29, tzinfo=SimpleTZ("Z")),
#   25.721831080983826],
#  [1.557908,
#   41.973725,
#   735.12,
#   datetime.datetime(2019, 6, 2, 8, 55, 30, tzinfo=SimpleTZ("Z")),
#   26.545153323758743],
#  [1.557861,
#   41.973782,
#   735.178,
#   datetime.datetime(2019, 6, 2, 8, 55, 31, tzinfo=SimpleTZ("Z")),
#   27.55313229499038],
#  [1.557818,
#   41.973845,
#   735.133,
#   datetime.datetime(2019, 6, 2, 8, 55, 32, tzinfo=SimpleTZ("Z")),
#   28.786222258372295],
#  [1.557776,
#   41.973911,
#   735.126,
#   datetime.datetime(2019, 6, 2, 8, 55, 33, tzinfo=SimpleTZ("Z")),
#   29.751715937168754],
#  [1.557732,
#   41.973979,
#   735.008,
#   datetime.datetime(2019, 6, 2, 8, 55, 34, tzinfo=SimpleTZ("Z")),
#   30.474561755956863],
#  [1.557682,
#   41.974046,
#   735.02,
#   datetime.datetime(2019, 6, 2, 8, 55, 35, tzinfo=SimpleTZ("Z")),
#   31.007112042198468],
#  [1.557624,
#   41.974111,
#   734.534,
#   datetime.datetime(2019, 6, 2, 8, 55, 36, tzinfo=SimpleTZ("Z")),
#   31.630441058587742],
#  [1.557562,
#   41.974176,
#   734.228,
#   datetime.datetime(2019, 6, 2, 8, 55, 37, tzinfo=SimpleTZ("Z")),
#   32.291580413862974],
#  [1.5575,
#   41.974243,
#   733.78,
#   datetime.datetime(2019, 6, 2, 8, 55, 38, tzinfo=SimpleTZ("Z")),
#   32.637340531540865],
#  [1.55744,
#   41.974311,
#   733.263,
#   datetime.datetime(2019, 6, 2, 8, 55, 39, tzinfo=SimpleTZ("Z")),
#   33.07686457250226],
#  [1.557383,
#   41.974383,
#   732.876,
#   datetime.datetime(2019, 6, 2, 8, 55, 40, tzinfo=SimpleTZ("Z")),
#   33.75179831678513],
#  [1.557325,
#   41.974456,
#   732.579,
#   datetime.datetime(2019, 6, 2, 8, 55, 41, tzinfo=SimpleTZ("Z")),
#   34.06803303512862],
#  [1.557266,
#   41.974529,
#   732.323,
#   datetime.datetime(2019, 6, 2, 8, 55, 42, tzinfo=SimpleTZ("Z")),
#   34.558297744949286],
#  [1.557206,
#   41.974604,
#   732.175,
#   datetime.datetime(2019, 6, 2, 8, 55, 43, tzinfo=SimpleTZ("Z")),
#   35.126890928536795],
#  [1.557144,
#   41.974679,
#   732.228,
#   datetime.datetime(2019, 6, 2, 8, 55, 44, tzinfo=SimpleTZ("Z")),
#   34.9068738662774],
#  [1.557083,
#   41.974752,
#   731.52,
#   datetime.datetime(2019, 6, 2, 8, 55, 45, tzinfo=SimpleTZ("Z")),
#   33.71610322629511],
#  [1.557025,
#   41.974821,
#   730.308,
#   datetime.datetime(2019, 6, 2, 8, 55, 46, tzinfo=SimpleTZ("Z")),
#   31.671617057691776],
#  [1.556975,
#   41.974887,
#   729.66,
#   datetime.datetime(2019, 6, 2, 8, 55, 47, tzinfo=SimpleTZ("Z")),
#   29.099773795074665],
#  [1.556929,
#   41.974947,
#   729.084,
#   datetime.datetime(2019, 6, 2, 8, 55, 48, tzinfo=SimpleTZ("Z")),
#   26.88881329214683],
#  [1.556883,
#   41.975002,
#   728.558,
#   datetime.datetime(2019, 6, 2, 8, 55, 49, tzinfo=SimpleTZ("Z")),
#   26.422644516946665],
#  [1.55683,
#   41.975056,
#   728.19,
#   datetime.datetime(2019, 6, 2, 8, 55, 50, tzinfo=SimpleTZ("Z")),
#   26.638789492215636],
#  [1.556779,
#   41.97511,
#   727.953,
#   datetime.datetime(2019, 6, 2, 8, 55, 51, tzinfo=SimpleTZ("Z")),
#   27.140529248328576],
#  [1.556732,
#   41.97517,
#   727.956,
#   datetime.datetime(2019, 6, 2, 8, 55, 52, tzinfo=SimpleTZ("Z")),
#   27.92525209074528],
#  [1.556686,
#   41.975231,
#   727.949,
#   datetime.datetime(2019, 6, 2, 8, 55, 53, tzinfo=SimpleTZ("Z")),
#   28.473756346670864],
#  [1.556644,
#   41.975296,
#   727.623,
#   datetime.datetime(2019, 6, 2, 8, 55, 54, tzinfo=SimpleTZ("Z")),
#   29.21573106650595],
#  [1.556603,
#   41.975363,
#   727.399,
#   datetime.datetime(2019, 6, 2, 8, 55, 55, tzinfo=SimpleTZ("Z")),
#   29.507806344328298],
#  [1.556562,
#   41.97543,
#   727.207,
#   datetime.datetime(2019, 6, 2, 8, 55, 56, tzinfo=SimpleTZ("Z")),
#   29.87637830752891],
#  [1.556521,
#   41.975499,
#   726.927,
#   datetime.datetime(2019, 6, 2, 8, 55, 57, tzinfo=SimpleTZ("Z")),
#   30.360874075778387],
#  [1.556478,
#   41.975568,
#   726.908,
#   datetime.datetime(2019, 6, 2, 8, 55, 58, tzinfo=SimpleTZ("Z")),
#   30.428214920086067],
#  [1.556433,
#   41.975636,
#   727.132,
#   datetime.datetime(2019, 6, 2, 8, 55, 59, tzinfo=SimpleTZ("Z")),
#   30.581706376772008],
#  [1.556388,
#   41.975705,
#   726.636,
#   datetime.datetime(2019, 6, 2, 8, 56, tzinfo=SimpleTZ("Z")),
#   30.944879535096764],
#  [1.556343,
#   41.975775,
#   726.36,
#   datetime.datetime(2019, 6, 2, 8, 56, 1, tzinfo=SimpleTZ("Z")),
#   31.345103465303925],
#  [1.5563,
#   41.975847,
#   726.112,
#   datetime.datetime(2019, 6, 2, 8, 56, 2, tzinfo=SimpleTZ("Z")),
#   31.70139512618519],
#  [1.556258,
#   41.97592,
#   726.025,
#   datetime.datetime(2019, 6, 2, 8, 56, 3, tzinfo=SimpleTZ("Z")),
#   32.00291956076287],
#  [1.556213,
#   41.975993,
#   726.188,
#   datetime.datetime(2019, 6, 2, 8, 56, 4, tzinfo=SimpleTZ("Z")),
#   31.970307918447084],
#  [1.556166,
#   41.976064,
#   725.731,
#   datetime.datetime(2019, 6, 2, 8, 56, 5, tzinfo=SimpleTZ("Z")),
#   31.927779058080148],
#  [1.556119,
#   41.976136,
#   725.355,
#   datetime.datetime(2019, 6, 2, 8, 56, 6, tzinfo=SimpleTZ("Z")),
#   32.20510953976372],
#  [1.556073,
#   41.976209,
#   725.218,
#   datetime.datetime(2019, 6, 2, 8, 56, 7, tzinfo=SimpleTZ("Z")),
#   32.443370860183],
#  [1.556031,
#   41.976284,
#   724.898,
#   datetime.datetime(2019, 6, 2, 8, 56, 8, tzinfo=SimpleTZ("Z")),
#   32.89007330053512],
#  [1.55599,
#   41.976361,
#   724.617,
#   datetime.datetime(2019, 6, 2, 8, 56, 9, tzinfo=SimpleTZ("Z")),
#   33.492353161981875],
#  [1.555947,
#   41.976439,
#   724.608,
#   datetime.datetime(2019, 6, 2, 8, 56, 10, tzinfo=SimpleTZ("Z")),
#   33.654291502958245],
#  [1.555903,
#   41.976516,
#   724.594,
#   datetime.datetime(2019, 6, 2, 8, 56, 11, tzinfo=SimpleTZ("Z")),
#   33.70647092355415],
#  [1.555856,
#   41.976593,
#   724.578,
#   datetime.datetime(2019, 6, 2, 8, 56, 12, tzinfo=SimpleTZ("Z")),
#   33.919889561515525],
#  [1.555806,
#   41.976669,
#   724.072,
#   datetime.datetime(2019, 6, 2, 8, 56, 13, tzinfo=SimpleTZ("Z")),
#   33.96342887059147],
#  [1.555753,
#   41.976744,
#   723.734,
#   datetime.datetime(2019, 6, 2, 8, 56, 14, tzinfo=SimpleTZ("Z")),
#   33.63871687901121],
#  [1.555695,
#   41.976815,
#   723.457,
#   datetime.datetime(2019, 6, 2, 8, 56, 15, tzinfo=SimpleTZ("Z")),
#   32.34921635244481],
#  [1.555648,
#   41.976885,
#   723.01,
#   datetime.datetime(2019, 6, 2, 8, 56, 16, tzinfo=SimpleTZ("Z")),
#   29.927278446510343],
#  [1.555633,
#   41.976955,
#   722.523,
#   datetime.datetime(2019, 6, 2, 8, 56, 17, tzinfo=SimpleTZ("Z")),
#   27.339617485364204],
#  [1.555661,
#   41.977017,
#   722.327,
#   datetime.datetime(2019, 6, 2, 8, 56, 18, tzinfo=SimpleTZ("Z")),
#   25.743077626086627],
#  [1.555687,
#   41.977077,
#   722.471,
#   datetime.datetime(2019, 6, 2, 8, 56, 19, tzinfo=SimpleTZ("Z")),
#   25.129086909187688],
#  [1.555749,
#   41.977119,
#   722.541,
#   datetime.datetime(2019, 6, 2, 8, 56, 20, tzinfo=SimpleTZ("Z")),
#   24.694256920987133],
#  [1.555816,
#   41.977154,
#   722.615,
#   datetime.datetime(2019, 6, 2, 8, 56, 21, tzinfo=SimpleTZ("Z")),
#   24.284260414438382],
#  [1.555883,
#   41.977188,
#   722.508,
#   datetime.datetime(2019, 6, 2, 8, 56, 22, tzinfo=SimpleTZ("Z")),
#   23.949827541049793],
#  [1.55595,
#   41.97722,
#   722.62,
#   datetime.datetime(2019, 6, 2, 8, 56, 23, tzinfo=SimpleTZ("Z")),
#   23.349069436469726],
#  [1.556011,
#   41.977255,
#   722.834,
#   datetime.datetime(2019, 6, 2, 8, 56, 24, tzinfo=SimpleTZ("Z")),
#   22.600007533371404],
#  [1.556064,
#   41.977294,
#   722.618,
#   datetime.datetime(2019, 6, 2, 8, 56, 25, tzinfo=SimpleTZ("Z")),
#   22.06304430951697],
#  [1.556111,
#   41.977336,
#   722.68,
#   datetime.datetime(2019, 6, 2, 8, 56, 26, tzinfo=SimpleTZ("Z")),
#   21.846079587290895],
#  [1.556154,
#   41.97738,
#   722.613,
#   datetime.datetime(2019, 6, 2, 8, 56, 27, tzinfo=SimpleTZ("Z")),
#   21.551625509053476],
#  [1.556194,
#   41.977424,
#   722.896,
#   datetime.datetime(2019, 6, 2, 8, 56, 28, tzinfo=SimpleTZ("Z")),
#   21.740783895696143],
#  [1.556231,
#   41.977472,
#   723.019,
#   datetime.datetime(2019, 6, 2, 8, 56, 29, tzinfo=SimpleTZ("Z")),
#   22.182391417999842],
#  [1.556263,
#   41.977522,
#   723.023,
#   datetime.datetime(2019, 6, 2, 8, 56, 30, tzinfo=SimpleTZ("Z")),
#   21.90907383893876],
#  [1.55629,
#   41.977572,
#   723.372,
#   datetime.datetime(2019, 6, 2, 8, 56, 31, tzinfo=SimpleTZ("Z")),
#   21.541087364283925],
#  [1.556319,
#   41.977621,
#   723.413,
#   datetime.datetime(2019, 6, 2, 8, 56, 32, tzinfo=SimpleTZ("Z")),
#   21.604915424022924],
#  [1.556344,
#   41.977672,
#   723.314,
#   datetime.datetime(2019, 6, 2, 8, 56, 33, tzinfo=SimpleTZ("Z")),
#   21.489901312688485],
#  [1.556371,
#   41.977721,
#   723.208,
#   datetime.datetime(2019, 6, 2, 8, 56, 34, tzinfo=SimpleTZ("Z")),
#   21.596985553416037],
#  [1.556398,
#   41.977772,
#   723.35,
#   datetime.datetime(2019, 6, 2, 8, 56, 35, tzinfo=SimpleTZ("Z")),
#   22.293558377297234],
#  [1.556424,
#   41.977825,
#   723.174,
#   datetime.datetime(2019, 6, 2, 8, 56, 36, tzinfo=SimpleTZ("Z")),
#   22.59349968469166],
#  [1.556453,
#   41.977877,
#   722.978,
#   datetime.datetime(2019, 6, 2, 8, 56, 37, tzinfo=SimpleTZ("Z")),
#   22.75182329750763],
#  [1.556482,
#   41.97793,
#   722.86,
#   datetime.datetime(2019, 6, 2, 8, 56, 38, tzinfo=SimpleTZ("Z")),
#   22.691752029602107],
#  [1.55651,
#   41.977982,
#   722.753,
#   datetime.datetime(2019, 6, 2, 8, 56, 39, tzinfo=SimpleTZ("Z")),
#   20.65033428117753],
#  [1.556532,
#   41.978026,
#   722.416,
#   datetime.datetime(2019, 6, 2, 8, 56, 40, tzinfo=SimpleTZ("Z")),
#   17.19045506509132],
#  [1.556566,
#   41.978099,
#   721.719,
#   datetime.datetime(2019, 6, 2, 8, 56, 42, tzinfo=SimpleTZ("Z")),
#   13.303453048454625],
#  [1.5566,
#   41.978148,
#   721.273,
#   datetime.datetime(2019, 6, 2, 8, 56, 44, tzinfo=SimpleTZ("Z")),
#   6.508299798031504],
#  [1.556628,
#   41.978207,
#   720.523,
#   datetime.datetime(2019, 6, 2, 8, 56, 57, tzinfo=SimpleTZ("Z")),
#   8.35629399523194],
#  [1.556643,
#   41.978317,
#   720.783,
#   datetime.datetime(2019, 6, 2, 8, 57, tzinfo=SimpleTZ("Z")),
#   16.04112547729831],
#  [1.556633,
#   41.978403,
#   720.411,
#   datetime.datetime(2019, 6, 2, 8, 57, 2, tzinfo=SimpleTZ("Z")),
#   19.00704684250572],
#  [1.556611,
#   41.978452,
#   720.508,
#   datetime.datetime(2019, 6, 2, 8, 57, 3, tzinfo=SimpleTZ("Z")),
#   21.750047602840656],
#  [1.55658,
#   41.978504,
#   720.585,
#   datetime.datetime(2019, 6, 2, 8, 57, 4, tzinfo=SimpleTZ("Z")),
#   23.836332896961608],
#  [1.556544,
#   41.97856,
#   720.459,
#   datetime.datetime(2019, 6, 2, 8, 57, 5, tzinfo=SimpleTZ("Z")),
#   25.010895670168047],
#  [1.556509,
#   41.978617,
#   720.093,
#   datetime.datetime(2019, 6, 2, 8, 57, 6, tzinfo=SimpleTZ("Z")),
#   26.448712713415432],
#  [1.556465,
#   41.978678,
#   719.845,
#   datetime.datetime(2019, 6, 2, 8, 57, 7, tzinfo=SimpleTZ("Z")),
#   28.105439152888923],
#  [1.556421,
#   41.978741,
#   719.628,
#   datetime.datetime(2019, 6, 2, 8, 57, 8, tzinfo=SimpleTZ("Z")),
#   28.809681856762694],
#  [1.556377,
#   41.978806,
#   719.591,
#   datetime.datetime(2019, 6, 2, 8, 57, 9, tzinfo=SimpleTZ("Z")),
#   29.65031165145958],
#  [1.556329,
#   41.978872,
#   719.014,
#   datetime.datetime(2019, 6, 2, 8, 57, 10, tzinfo=SimpleTZ("Z")),
#   30.282010620133132],
#  [1.556281,
#   41.978939,
#   718.878,
#   datetime.datetime(2019, 6, 2, 8, 57, 11, tzinfo=SimpleTZ("Z")),
#   31.013066897279643],
#  [1.556235,
#   41.97901,
#   718.566,
#   datetime.datetime(2019, 6, 2, 8, 57, 12, tzinfo=SimpleTZ("Z")),
#   32.0933394814907],
#  [1.556187,
#   41.979083,
#   718.229,
#   datetime.datetime(2019, 6, 2, 8, 57, 13, tzinfo=SimpleTZ("Z")),
#   33.120247288594896],
#  [1.556139,
#   41.979159,
#   718.021,
#   datetime.datetime(2019, 6, 2, 8, 57, 14, tzinfo=SimpleTZ("Z")),
#   34.149893381361736],
#  [1.556089,
#   41.979237,
#   717.708,
#   datetime.datetime(2019, 6, 2, 8, 57, 15, tzinfo=SimpleTZ("Z")),
#   35.02125115124013],
#  [1.556036,
#   41.979316,
#   717.379,
#   datetime.datetime(2019, 6, 2, 8, 57, 16, tzinfo=SimpleTZ("Z")),
#   35.425050595176906],
#  [1.555983,
#   41.979395,
#   716.743,
#   datetime.datetime(2019, 6, 2, 8, 57, 17, tzinfo=SimpleTZ("Z")),
#   35.60887921215981],
#  [1.55593,
#   41.979475,
#   716.347,
#   datetime.datetime(2019, 6, 2, 8, 57, 18, tzinfo=SimpleTZ("Z")),
#   35.98804562633587],
#  [1.555879,
#   41.979557,
#   716.539,
#   datetime.datetime(2019, 6, 2, 8, 57, 19, tzinfo=SimpleTZ("Z")),
#   36.588190234165026],
#  [1.555825,
#   41.97964,
#   716.222,
#   datetime.datetime(2019, 6, 2, 8, 57, 20, tzinfo=SimpleTZ("Z")),
#   36.732119932448036],
#  [1.555772,
#   41.979722,
#   715.745,
#   datetime.datetime(2019, 6, 2, 8, 57, 21, tzinfo=SimpleTZ("Z")),
#   36.471779566080045],
#  [1.555722,
#   41.979805,
#   715.748,
#   datetime.datetime(2019, 6, 2, 8, 57, 22, tzinfo=SimpleTZ("Z")),
#   36.521086597673914],
#  [1.555668,
#   41.979887,
#   715.522,
#   datetime.datetime(2019, 6, 2, 8, 57, 23, tzinfo=SimpleTZ("Z")),
#   36.7871901024165],
#  [1.555614,
#   41.97997,
#   715.114,
#   datetime.datetime(2019, 6, 2, 8, 57, 24, tzinfo=SimpleTZ("Z")),
#   36.71993149258672],
#  [1.555561,
#   41.980052,
#   714.954,
#   datetime.datetime(2019, 6, 2, 8, 57, 25, tzinfo=SimpleTZ("Z")),
#   36.523496847263715],
#  [1.555508,
#   41.980134,
#   714.109,
#   datetime.datetime(2019, 6, 2, 8, 57, 26, tzinfo=SimpleTZ("Z")),
#   36.29063683722205],
#  [1.555456,
#   41.980215,
#   713.708,
#   datetime.datetime(2019, 6, 2, 8, 57, 27, tzinfo=SimpleTZ("Z")),
#   36.04751575513073],
#  [1.555403,
#   41.980296,
#   713.624,
#   datetime.datetime(2019, 6, 2, 8, 57, 28, tzinfo=SimpleTZ("Z")),
#   35.78829463005635],
#  [1.555352,
#   41.980376,
#   713.578,
#   datetime.datetime(2019, 6, 2, 8, 57, 29, tzinfo=SimpleTZ("Z")),
#   35.116974053035676],
#  [1.555301,
#   41.980454,
#   713.532,
#   datetime.datetime(2019, 6, 2, 8, 57, 30, tzinfo=SimpleTZ("Z")),
#   34.51078542843858],
#  [1.555251,
#   41.980531,
#   713.454,
#   datetime.datetime(2019, 6, 2, 8, 57, 31, tzinfo=SimpleTZ("Z")),
#   34.26003267829409],
#  [1.555204,
#   41.980609,
#   713.327,
#   datetime.datetime(2019, 6, 2, 8, 57, 32, tzinfo=SimpleTZ("Z")),
#   34.193381747892566],
#  [1.555158,
#   41.980687,
#   713.22,
#   datetime.datetime(2019, 6, 2, 8, 57, 33, tzinfo=SimpleTZ("Z")),
#   34.01252260830508],
#  [1.555111,
#   41.980764,
#   713.033,
#   datetime.datetime(2019, 6, 2, 8, 57, 34, tzinfo=SimpleTZ("Z")),
#   33.70814351844656],
#  [1.555064,
#   41.98084,
#   712.917,
#   datetime.datetime(2019, 6, 2, 8, 57, 35, tzinfo=SimpleTZ("Z")),
#   33.54140036597962],
#  [1.555017,
#   41.980916,
#   712.475,
#   datetime.datetime(2019, 6, 2, 8, 57, 36, tzinfo=SimpleTZ("Z")),
#   33.5074268920221],
#  [1.554971,
#   41.980992,
#   711.928,
#   datetime.datetime(2019, 6, 2, 8, 57, 37, tzinfo=SimpleTZ("Z")),
#   33.3067066098171],
#  [1.554924,
#   41.981067,
#   711.92,
#   datetime.datetime(2019, 6, 2, 8, 57, 38, tzinfo=SimpleTZ("Z")),
#   33.16702736608902],
#  [1.554877,
#   41.981142,
#   711.608,
#   datetime.datetime(2019, 6, 2, 8, 57, 39, tzinfo=SimpleTZ("Z")),
#   33.16795258285017],
#  [1.55483,
#   41.981217,
#   711.51,
#   datetime.datetime(2019, 6, 2, 8, 57, 40, tzinfo=SimpleTZ("Z")),
#   33.22777181318483],
#  [1.554782,
#   41.981292,
#   711.264,
#   datetime.datetime(2019, 6, 2, 8, 57, 41, tzinfo=SimpleTZ("Z")),
#   33.49077637396129],
#  [1.554731,
#   41.981367,
#   711.068,
#   datetime.datetime(2019, 6, 2, 8, 57, 42, tzinfo=SimpleTZ("Z")),
#   33.79537104811657],
#  [1.554681,
#   41.981443,
#   710.99,
#   datetime.datetime(2019, 6, 2, 8, 57, 43, tzinfo=SimpleTZ("Z")),
#   33.9828624426457],
#  [1.55463,
#   41.981519,
#   710.633,
#   datetime.datetime(2019, 6, 2, 8, 57, 44, tzinfo=SimpleTZ("Z")),
#   33.92676034976432],
#  [1.554581,
#   41.981595,
#   710.946,
#   datetime.datetime(2019, 6, 2, 8, 57, 45, tzinfo=SimpleTZ("Z")),
#   33.984476959840514],
#  [1.554532,
#   41.981672,
#   710.489,
#   datetime.datetime(2019, 6, 2, 8, 57, 46, tzinfo=SimpleTZ("Z")),
#   34.04486213432318],
#  [1.554482,
#   41.981748,
#   710.263,
#   datetime.datetime(2019, 6, 2, 8, 57, 47, tzinfo=SimpleTZ("Z")),
#   34.026850760083946],
#  [1.554433,
#   41.981825,
#   710.125,
#   datetime.datetime(2019, 6, 2, 8, 57, 48, tzinfo=SimpleTZ("Z")),
#   34.271193906064944],
#  [1.554382,
#   41.981902,
#   709.926,
#   datetime.datetime(2019, 6, 2, 8, 57, 49, tzinfo=SimpleTZ("Z")),
#   34.36393119138458],
#  [1.554329,
#   41.981978,
#   709.608,
#   datetime.datetime(2019, 6, 2, 8, 57, 50, tzinfo=SimpleTZ("Z")),
#   34.42744197806601],
#  [1.554277,
#   41.982055,
#   709.508,
#   datetime.datetime(2019, 6, 2, 8, 57, 51, tzinfo=SimpleTZ("Z")),
#   34.46319100003967],
#  [1.554226,
#   41.982132,
#   709.415,
#   datetime.datetime(2019, 6, 2, 8, 57, 52, tzinfo=SimpleTZ("Z")),
#   34.46549048895351],
#  [1.554174,
#   41.982209,
#   709.229,
#   datetime.datetime(2019, 6, 2, 8, 57, 53, tzinfo=SimpleTZ("Z")),
#   34.46494220299793],
#  [1.554123,
#   41.982286,
#   709.283,
#   datetime.datetime(2019, 6, 2, 8, 57, 54, tzinfo=SimpleTZ("Z")),
#   34.17373784774639],
#  [1.55407,
#   41.982361,
#   709.355,
#   datetime.datetime(2019, 6, 2, 8, 57, 55, tzinfo=SimpleTZ("Z")),
#   33.706032931427856],
#  [1.554018,
#   41.982435,
#   709.238,
#   datetime.datetime(2019, 6, 2, 8, 57, 56, tzinfo=SimpleTZ("Z")),
#   33.572423921396506],
#  [1.553967,
#   41.98251,
#   709.051,
#   datetime.datetime(2019, 6, 2, 8, 57, 57, tzinfo=SimpleTZ("Z")),
#   33.55007134370263],
#  [1.553918,
#   41.982585,
#   708.944,
#   datetime.datetime(2019, 6, 2, 8, 57, 58, tzinfo=SimpleTZ("Z")),
#   33.661841567723016],
#  [1.553868,
#   41.982661,
#   708.798,
#   datetime.datetime(2019, 6, 2, 8, 57, 59, tzinfo=SimpleTZ("Z")),
#   33.793016661248856],
#  [1.553817,
#   41.982736,
#   708.813,
#   datetime.datetime(2019, 6, 2, 8, 58, tzinfo=SimpleTZ("Z")),
#   33.61399118594543],
#  [1.553767,
#   41.982811,
#   708.643,
#   datetime.datetime(2019, 6, 2, 8, 58, 1, tzinfo=SimpleTZ("Z")),
#   33.35634611967858],
#  [1.55372,
#   41.982886,
#   708.807,
#   datetime.datetime(2019, 6, 2, 8, 58, 2, tzinfo=SimpleTZ("Z")),
#   32.987384602658864],
#  [1.553673,
#   41.98296,
#   708.508,
#   datetime.datetime(2019, 6, 2, 8, 58, 3, tzinfo=SimpleTZ("Z")),
#   32.805160484562656],
#  [1.553626,
#   41.983034,
#   708.644,
#   datetime.datetime(2019, 6, 2, 8, 58, 4, tzinfo=SimpleTZ("Z")),
#   32.63347244279773],
#  [1.553579,
#   41.983107,
#   708.218,
#   datetime.datetime(2019, 6, 2, 8, 58, 5, tzinfo=SimpleTZ("Z")),
#   32.46878735408918],
#  [1.553532,
#   41.98318,
#   707.792,
#   datetime.datetime(2019, 6, 2, 8, 58, 6, tzinfo=SimpleTZ("Z")),
#   32.51769482501663],
#  [1.553484,
#   41.983253,
#   707.644,
#   datetime.datetime(2019, 6, 2, 8, 58, 7, tzinfo=SimpleTZ("Z")),
#   32.6319750479637],
#  [1.553435,
#   41.983326,
#   707.517,
#   datetime.datetime(2019, 6, 2, 8, 58, 8, tzinfo=SimpleTZ("Z")),
#   32.58469420153141],
#  [1.553385,
#   41.983398,
#   707.47,
#   datetime.datetime(2019, 6, 2, 8, 58, 9, tzinfo=SimpleTZ("Z")),
#   32.29431433092613],
#  [1.553335,
#   41.983469,
#   707.523,
#   datetime.datetime(2019, 6, 2, 8, 58, 10, tzinfo=SimpleTZ("Z")),
#   32.1614261078272],
#  [1.553287,
#   41.983541,
#   707.657,
#   datetime.datetime(2019, 6, 2, 8, 58, 11, tzinfo=SimpleTZ("Z")),
#   32.21554377735301],
#  [1.553239,
#   41.983613,
#   707.325,
#   datetime.datetime(2019, 6, 2, 8, 58, 12, tzinfo=SimpleTZ("Z")),
#   32.03846857905923],
#  [1.553191,
#   41.983684,
#   707.126,
#   datetime.datetime(2019, 6, 2, 8, 58, 13, tzinfo=SimpleTZ("Z")),
#   31.961827591016604],
#  [1.553144,
#   41.983756,
#   707.108,
#   datetime.datetime(2019, 6, 2, 8, 58, 14, tzinfo=SimpleTZ("Z")),
#   31.892491585630083],
#  [1.553097,
#   41.983827,
#   707.008,
#   datetime.datetime(2019, 6, 2, 8, 58, 15, tzinfo=SimpleTZ("Z")),
#   31.58339745364837],
#  [1.553052,
#   41.983898,
#   707.055,
#   datetime.datetime(2019, 6, 2, 8, 58, 16, tzinfo=SimpleTZ("Z")),
#   31.453188843113924],
#  [1.553007,
#   41.983969,
#   707.029,
#   datetime.datetime(2019, 6, 2, 8, 58, 17, tzinfo=SimpleTZ("Z")),
#   31.336741754495495],
#  [1.552961,
#   41.984039,
#   707.043,
#   datetime.datetime(2019, 6, 2, 8, 58, 18, tzinfo=SimpleTZ("Z")),
#   31.047095178678777],
#  [1.552915,
#   41.984108,
#   706.795,
#   datetime.datetime(2019, 6, 2, 8, 58, 19, tzinfo=SimpleTZ("Z")),
#   30.755491661506504],
#  [1.552868,
#   41.984176,
#   706.788,
#   datetime.datetime(2019, 6, 2, 8, 58, 20, tzinfo=SimpleTZ("Z")),
#   30.57271169953651],
#  [1.552822,
#   41.984244,
#   706.621,
#   datetime.datetime(2019, 6, 2, 8, 58, 21, tzinfo=SimpleTZ("Z")),
#   30.47016859011965],
#  [1.552774,
#   41.984311,
#   706.384,
#   datetime.datetime(2019, 6, 2, 8, 58, 22, tzinfo=SimpleTZ("Z")),
#   30.29377925144843],
#  [1.552723,
#   41.984376,
#   706.368,
#   datetime.datetime(2019, 6, 2, 8, 58, 23, tzinfo=SimpleTZ("Z")),
#   30.22089343502186],
#  [1.552667,
#   41.984439,
#   706.021,
#   datetime.datetime(2019, 6, 2, 8, 58, 24, tzinfo=SimpleTZ("Z")),
#   30.534942755083176],
#  [1.552606,
#   41.984501,
#   705.941,
#   datetime.datetime(2019, 6, 2, 8, 58, 25, tzinfo=SimpleTZ("Z")),
#   30.519659613630346],
#  [1.552541,
#   41.984559,
#   705.805,
#   datetime.datetime(2019, 6, 2, 8, 58, 26, tzinfo=SimpleTZ("Z")),
#   30.504121392651314],
#  [1.552475,
#   41.984618,
#   705.708,
#   datetime.datetime(2019, 6, 2, 8, 58, 27, tzinfo=SimpleTZ("Z")),
#   30.890928436887283],
#  [1.552406,
#   41.984676,
#   705.625,
#   datetime.datetime(2019, 6, 2, 8, 58, 28, tzinfo=SimpleTZ("Z")),
#   31.187341053089163],
#  [1.552334,
#   41.984733,
#   705.389,
#   datetime.datetime(2019, 6, 2, 8, 58, 29, tzinfo=SimpleTZ("Z")),
#   31.54486937454501],
#  [1.55226,
#   41.98479,
#   705.393,
#   datetime.datetime(2019, 6, 2, 8, 58, 30, tzinfo=SimpleTZ("Z")),
#   31.647241057073707],
#  [1.552187,
#   41.984847,
#   705.155,
#   datetime.datetime(2019, 6, 2, 8, 58, 31, tzinfo=SimpleTZ("Z")),
#   31.657478962632414],
#  [1.552113,
#   41.984904,
#   704.838,
#   datetime.datetime(2019, 6, 2, 8, 58, 32, tzinfo=SimpleTZ("Z")),
#   31.89995498421003],
#  [1.552039,
#   41.984962,
#   704.771,
#   datetime.datetime(2019, 6, 2, 8, 58, 33, tzinfo=SimpleTZ("Z")),
#   32.010262746844376],
#  [1.551964,
#   41.985019,
#   704.364,
#   datetime.datetime(2019, 6, 2, 8, 58, 34, tzinfo=SimpleTZ("Z")),
#   31.86662431740973],
#  [1.55189,
#   41.985076,
#   704.238,
#   datetime.datetime(2019, 6, 2, 8, 58, 35, tzinfo=SimpleTZ("Z")),
#   31.67224400444807],
#  [1.551814,
#   41.985131,
#   704.217,
#   datetime.datetime(2019, 6, 2, 8, 58, 36, tzinfo=SimpleTZ("Z")),
#   31.52754354615646],
#  [1.55174,
#   41.985187,
#   704.287,
#   datetime.datetime(2019, 6, 2, 8, 58, 37, tzinfo=SimpleTZ("Z")),
#   31.258185154618506],
#  [1.551668,
#   41.985243,
#   704.015,
#   datetime.datetime(2019, 6, 2, 8, 58, 38, tzinfo=SimpleTZ("Z")),
#   31.06021538282182],
#  [1.551596,
#   41.985299,
#   703.708,
#   datetime.datetime(2019, 6, 2, 8, 58, 39, tzinfo=SimpleTZ("Z")),
#   31.053886752557666],
#  [1.551524,
#   41.985355,
#   703.824,
#   datetime.datetime(2019, 6, 2, 8, 58, 40, tzinfo=SimpleTZ("Z")),
#   31.114314851913555],
#  [1.55145,
#   41.98541,
#   703.598,
#   datetime.datetime(2019, 6, 2, 8, 58, 41, tzinfo=SimpleTZ("Z")),
#   30.97668420611652],
#  [1.551378,
#   41.985465,
#   703.322,
#   datetime.datetime(2019, 6, 2, 8, 58, 42, tzinfo=SimpleTZ("Z")),
#   30.86703528885656],
#  [1.551305,
#   41.98552,
#   703.244,
#   datetime.datetime(2019, 6, 2, 8, 58, 43, tzinfo=SimpleTZ("Z")),
#   30.793921818890183],
#  [1.551231,
#   41.985573,
#   702.997,
#   datetime.datetime(2019, 6, 2, 8, 58, 44, tzinfo=SimpleTZ("Z")),
#   30.61764531602469],
#  [1.551157,
#   41.985626,
#   702.96,
#   datetime.datetime(2019, 6, 2, 8, 58, 45, tzinfo=SimpleTZ("Z")),
#   30.733682963424904],
#  [1.551086,
#   41.985682,
#   702.663,
#   datetime.datetime(2019, 6, 2, 8, 58, 46, tzinfo=SimpleTZ("Z")),
#   30.82884047792123],
#  [1.551025,
#   41.985744,
#   702.357,
#   datetime.datetime(2019, 6, 2, 8, 58, 47, tzinfo=SimpleTZ("Z")),
#   30.70427476839625],
#  [1.550981,
#   41.985813,
#   702.187,
#   datetime.datetime(2019, 6, 2, 8, 58, 48, tzinfo=SimpleTZ("Z")),
#   30.50163524570591],
#  [1.550959,
#   41.985887,
#   701.842,
#   datetime.datetime(2019, 6, 2, 8, 58, 49, tzinfo=SimpleTZ("Z")),
#   29.863451094133243],
#  [1.550952,
#   41.98596,
#   701.926,
#   datetime.datetime(2019, 6, 2, 8, 58, 50, tzinfo=SimpleTZ("Z")),
#   29.221660493645267],
#  [1.550939,
#   41.986032,
#   701.908,
#   datetime.datetime(2019, 6, 2, 8, 58, 51, tzinfo=SimpleTZ("Z")),
#   28.802804433107717],
#  [1.550907,
#   41.986099,
#   701.851,
#   datetime.datetime(2019, 6, 2, 8, 58, 52, tzinfo=SimpleTZ("Z")),
#   28.406531437474577],
#  [1.550859,
#   41.98616,
#   701.845,
#   datetime.datetime(2019, 6, 2, 8, 58, 53, tzinfo=SimpleTZ("Z")),
#   28.5911403269293],
#  [1.550788,
#   41.986209,
#   701.939,
#   datetime.datetime(2019, 6, 2, 8, 58, 54, tzinfo=SimpleTZ("Z")),
#   29.208300652245647],
#  [1.5507,
#   41.986243,
#   701.711,
#   datetime.datetime(2019, 6, 2, 8, 58, 55, tzinfo=SimpleTZ("Z")),
#   29.77171003805942],
#  [1.550603,
#   41.986263,
#   701.584,
#   datetime.datetime(2019, 6, 2, 8, 58, 56, tzinfo=SimpleTZ("Z")),
#   30.15106924818264],
#  [1.550502,
#   41.986272,
#   701.347,
#   datetime.datetime(2019, 6, 2, 8, 58, 57, tzinfo=SimpleTZ("Z")),
#   30.953999668787706],
#  [1.550398,
#   41.986287,
#   700.92,
#   datetime.datetime(2019, 6, 2, 8, 58, 58, tzinfo=SimpleTZ("Z")),
#   31.585332468640118],
#  [1.5503,
#   41.986317,
#   700.764,
#   datetime.datetime(2019, 6, 2, 8, 58, 59, tzinfo=SimpleTZ("Z")),
#   31.93456133937585],
#  [1.550211,
#   41.986363,
#   700.879,
#   datetime.datetime(2019, 6, 2, 8, 59, tzinfo=SimpleTZ("Z")),
#   32.470704077235204],
#  [1.550133,
#   41.98642,
#   700.305,
#   datetime.datetime(2019, 6, 2, 8, 59, 1, tzinfo=SimpleTZ("Z")),
#   32.63469960717194],
#  [1.550059,
#   41.98648,
#   700.225,
#   datetime.datetime(2019, 6, 2, 8, 59, 2, tzinfo=SimpleTZ("Z")),
#   32.62520395815207],
#  [1.549985,
#   41.98654,
#   700.008,
#   datetime.datetime(2019, 6, 2, 8, 59, 3, tzinfo=SimpleTZ("Z")),
#   32.73213721444248],
#  [1.54991,
#   41.9866,
#   699.75,
#   datetime.datetime(2019, 6, 2, 8, 59, 4, tzinfo=SimpleTZ("Z")),
#   32.889802712055086],
#  [1.549833,
#   41.986659,
#   699.624,
#   datetime.datetime(2019, 6, 2, 8, 59, 5, tzinfo=SimpleTZ("Z")),
#   32.993550819334224],
#  [1.549757,
#   41.986719,
#   699.328,
#   datetime.datetime(2019, 6, 2, 8, 59, 6, tzinfo=SimpleTZ("Z")),
#   33.13652370477997],
#  [1.54968,
#   41.986779,
#   699.29,
#   datetime.datetime(2019, 6, 2, 8, 59, 7, tzinfo=SimpleTZ("Z")),
#   33.24572596618455],
#  [1.549603,
#   41.986839,
#   698.893,
#   datetime.datetime(2019, 6, 2, 8, 59, 8, tzinfo=SimpleTZ("Z")),
#   33.42170949579238],
#  [1.549523,
#   41.986898,
#   698.636,
#   datetime.datetime(2019, 6, 2, 8, 59, 9, tzinfo=SimpleTZ("Z")),
#   33.40646776726085],
#  [1.549446,
#   41.986958,
#   698.599,
#   datetime.datetime(2019, 6, 2, 8, 59, 10, tzinfo=SimpleTZ("Z")),
#   33.48544932908754],
#  [1.549368,
#   41.987019,
#   698.323,
#   datetime.datetime(2019, 6, 2, 8, 59, 11, tzinfo=SimpleTZ("Z")),
#   33.55138604843489],
#  [1.549289,
#   41.987078,
#   698.456,
#   datetime.datetime(2019, 6, 2, 8, 59, 12, tzinfo=SimpleTZ("Z")),
#   33.25966735585379],
#  [1.549211,
#   41.987137,
#   698.259,
#   datetime.datetime(2019, 6, 2, 8, 59, 13, tzinfo=SimpleTZ("Z")),
#   33.16483525377179],
#  [1.549133,
#   41.987196,
#   697.914,
#   datetime.datetime(2019, 6, 2, 8, 59, 14, tzinfo=SimpleTZ("Z")),
#   33.05698377390037],
#  [1.549056,
#   41.987255,
#   697.908,
#   datetime.datetime(2019, 6, 2, 8, 59, 15, tzinfo=SimpleTZ("Z")),
#   32.79810504140666],
#  [1.548979,
#   41.987313,
#   697.928,
#   datetime.datetime(2019, 6, 2, 8, 59, 16, tzinfo=SimpleTZ("Z")),
#   32.728312583372805],
#  [1.5489,
#   41.98737,
#   697.752,
#   datetime.datetime(2019, 6, 2, 8, 59, 17, tzinfo=SimpleTZ("Z")),
#   32.500328912339796],
#  [1.54882,
#   41.987424,
#   697.966,
#   datetime.datetime(2019, 6, 2, 8, 59, 18, tzinfo=SimpleTZ("Z")),
#   32.253387040110944],
#  [1.548736,
#   41.987475,
#   697.978,
#   datetime.datetime(2019, 6, 2, 8, 59, 19, tzinfo=SimpleTZ("Z")),
#   32.3071750688835],
#  [1.548651,
#   41.987525,
#   697.681,
#   datetime.datetime(2019, 6, 2, 8, 59, 20, tzinfo=SimpleTZ("Z")),
#   32.41667773485502],
#  [1.548563,
#   41.987573,
#   697.424,
#   datetime.datetime(2019, 6, 2, 8, 59, 21, tzinfo=SimpleTZ("Z")),
#   32.657005423336166],
#  [1.548472,
#   41.987619,
#   697.247,
#   datetime.datetime(2019, 6, 2, 8, 59, 22, tzinfo=SimpleTZ("Z")),
#   32.705943041578834],
#  [1.548379,
#   41.987662,
#   697.221,
#   datetime.datetime(2019, 6, 2, 8, 59, 23, tzinfo=SimpleTZ("Z")),
#   32.67412933343782],
#  [1.548284,
#   41.987703,
#   697.139,
#   datetime.datetime(2019, 6, 2, 8, 59, 24, tzinfo=SimpleTZ("Z")),
#   32.843123324087934],
#  [1.548186,
#   41.987741,
#   696.701,
#   datetime.datetime(2019, 6, 2, 8, 59, 25, tzinfo=SimpleTZ("Z")),
#   32.85274690652837],
#  [1.548088,
#   41.987778,
#   696.621,
#   datetime.datetime(2019, 6, 2, 8, 59, 26, tzinfo=SimpleTZ("Z")),
#   32.57163073383202],
#  [1.547992,
#   41.987816,
#   696.508,
#   datetime.datetime(2019, 6, 2, 8, 59, 27, tzinfo=SimpleTZ("Z")),
#   32.36431894281925],
#  [1.547897,
#   41.987855,
#   696.436,
#   datetime.datetime(2019, 6, 2, 8, 59, 28, tzinfo=SimpleTZ("Z")),
#   32.232467626690166],
#  [1.547802,
#   41.987893,
#   696.35,
#   datetime.datetime(2019, 6, 2, 8, 59, 29, tzinfo=SimpleTZ("Z")),
#   32.00508897153198],
#  [1.547708,
#   41.987931,
#   696.324,
#   datetime.datetime(2019, 6, 2, 8, 59, 30, tzinfo=SimpleTZ("Z")),
#   31.742838062379384],
#  [1.547615,
#   41.987969,
#   696.366,
#   datetime.datetime(2019, 6, 2, 8, 59, 31, tzinfo=SimpleTZ("Z")),
#   31.385436695957498],
#  [1.547523,
#   41.988006,
#   696.389,
#   datetime.datetime(2019, 6, 2, 8, 59, 32, tzinfo=SimpleTZ("Z")),
#   31.17492575534705],
#  [1.547431,
#   41.988043,
#   695.992,
#   datetime.datetime(2019, 6, 2, 8, 59, 33, tzinfo=SimpleTZ("Z")),
#   31.141524000931593],
#  [1.54734,
#   41.988081,
#   695.935,
#   datetime.datetime(2019, 6, 2, 8, 59, 34, tzinfo=SimpleTZ("Z")),
#   30.962090281560506],
#  [1.54725,
#   41.988119,
#   695.989,
#   datetime.datetime(2019, 6, 2, 8, 59, 35, tzinfo=SimpleTZ("Z")),
#   30.739109666612503],
#  [1.54716,
#   41.988156,
#   695.771,
#   datetime.datetime(2019, 6, 2, 8, 59, 36, tzinfo=SimpleTZ("Z")),
#   30.739304564335715],
#  [1.54707,
#   41.988194,
#   695.841,
#   datetime.datetime(2019, 6, 2, 8, 59, 37, tzinfo=SimpleTZ("Z")),
#   30.476006600830633],
#  [1.546982,
#   41.988231,
#   695.715,
#   datetime.datetime(2019, 6, 2, 8, 59, 38, tzinfo=SimpleTZ("Z")),
#   30.11753799663515],
#  [1.546894,
#   41.988268,
#   695.708,
#   datetime.datetime(2019, 6, 2, 8, 59, 39, tzinfo=SimpleTZ("Z")),
#   30.185919158044964],
#  [1.546804,
#   41.988303,
#   695.69,
#   datetime.datetime(2019, 6, 2, 8, 59, 40, tzinfo=SimpleTZ("Z")),
#   29.993644555042028],
#  [1.546716,
#   41.988338,
#   695.784,
#   datetime.datetime(2019, 6, 2, 8, 59, 41, tzinfo=SimpleTZ("Z")),
#   29.379831397681688],
#  [1.54663,
#   41.988372,
#   696.028,
#   datetime.datetime(2019, 6, 2, 8, 59, 42, tzinfo=SimpleTZ("Z")),
#   28.797421989749232],
#  [1.546545,
#   41.988405,
#   695.94,
#   datetime.datetime(2019, 6, 2, 8, 59, 43, tzinfo=SimpleTZ("Z")),
#   28.56559568324563],
#  [1.54646,
#   41.988438,
#   695.953,
#   datetime.datetime(2019, 6, 2, 8, 59, 44, tzinfo=SimpleTZ("Z")),
#   28.214838221973338],
#  [1.546377,
#   41.98847,
#   696.196,
#   datetime.datetime(2019, 6, 2, 8, 59, 45, tzinfo=SimpleTZ("Z")),
#   27.822699614033212],
#  [1.546295,
#   41.988503,
#   696.339,
#   datetime.datetime(2019, 6, 2, 8, 59, 46, tzinfo=SimpleTZ("Z")),
#   27.552098817903516],
#  [1.546214,
#   41.988535,
#   696.333,
#   datetime.datetime(2019, 6, 2, 8, 59, 47, tzinfo=SimpleTZ("Z")),
#   27.32843012093681],
#  [1.546133,
#   41.988567,
#   696.134,
#   datetime.datetime(2019, 6, 2, 8, 59, 48, tzinfo=SimpleTZ("Z")),
#   27.296990783458792],
#  [1.546053,
#   41.9886,
#   695.955,
#   datetime.datetime(2019, 6, 2, 8, 59, 49, tzinfo=SimpleTZ("Z")),
#   26.935516014573434],
#  [1.545974,
#   41.988631,
#   695.91,
#   datetime.datetime(2019, 6, 2, 8, 59, 50, tzinfo=SimpleTZ("Z")),
#   26.445140545482317],
#  [1.545897,
#   41.988663,
#   695.808,
#   datetime.datetime(2019, 6, 2, 8, 59, 51, tzinfo=SimpleTZ("Z")),
#   26.057411211374692],
#  [1.545821,
#   41.988694,
#   696.026,
#   datetime.datetime(2019, 6, 2, 8, 59, 52, tzinfo=SimpleTZ("Z")),
#   25.57039048132803],
#  [1.545747,
#   41.988725,
#   696.15,
#   datetime.datetime(2019, 6, 2, 8, 59, 53, tzinfo=SimpleTZ("Z")),
#   25.076535543501016],
#  [1.545674,
#   41.988755,
#   696.184,
#   datetime.datetime(2019, 6, 2, 8, 59, 54, tzinfo=SimpleTZ("Z")),
#   24.75857652149394],
#  [1.545601,
#   41.988784,
#   695.946,
#   datetime.datetime(2019, 6, 2, 8, 59, 55, tzinfo=SimpleTZ("Z")),
#   24.369345663332087],
#  [1.545531,
#   41.988814,
#   695.949,
#   datetime.datetime(2019, 6, 2, 8, 59, 56, tzinfo=SimpleTZ("Z")),
#   23.971561411543803],
#  [1.545461,
#   41.988843,
#   695.832,
#   datetime.datetime(2019, 6, 2, 8, 59, 57, tzinfo=SimpleTZ("Z")),
#   23.77740655698993],
#  [1.545391,
#   41.988871,
#   695.915,
#   datetime.datetime(2019, 6, 2, 8, 59, 58, tzinfo=SimpleTZ("Z")),
#   23.548747700104023],
#  [1.545322,
#   41.988899,
#   695.969,
#   datetime.datetime(2019, 6, 2, 8, 59, 59, tzinfo=SimpleTZ("Z")),
#   23.54854636199582],
#  [1.545252,
#   41.988927,
#   695.895,
#   datetime.datetime(2019, 6, 2, 9, 0, tzinfo=SimpleTZ("Z")),
#   23.548427668995345],
#  [1.545183,
#   41.988955,
#   695.849,
#   datetime.datetime(2019, 6, 2, 9, 0, 1, tzinfo=SimpleTZ("Z")),
#   23.324262599841983],
#  [1.545114,
#   41.988982,
#   695.723,
#   datetime.datetime(2019, 6, 2, 9, 0, 2, tzinfo=SimpleTZ("Z")),
#   23.195312157519243],
#  [1.545046,
#   41.98901,
#   695.608,
#   datetime.datetime(2019, 6, 2, 9, 0, 3, tzinfo=SimpleTZ("Z")),
#   23.257495777127584],
#  [1.544978,
#   41.989039,
#   695.722,
#   datetime.datetime(2019, 6, 2, 9, 0, 4, tzinfo=SimpleTZ("Z")),
#   23.160689400635736],
#  [1.54491,
#   41.989066,
#   695.646,
#   datetime.datetime(2019, 6, 2, 9, 0, 5, tzinfo=SimpleTZ("Z")),
#   23.0614972471548],
#  [1.544842,
#   41.989094,
#   695.56,
#   datetime.datetime(2019, 6, 2, 9, 0, 6, tzinfo=SimpleTZ("Z")),
#   23.157084469022266],
#  [1.544774,
#   41.989122,
#   695.492,
#   datetime.datetime(2019, 6, 2, 9, 0, 7, tzinfo=SimpleTZ("Z")),
#   23.287362156514902],
#  [1.544705,
#   41.98915,
#   695.415,
#   datetime.datetime(2019, 6, 2, 9, 0, 8, tzinfo=SimpleTZ("Z")),
#   23.419654485401498],
#  [1.544636,
#   41.989178,
#   695.548,
#   datetime.datetime(2019, 6, 2, 9, 0, 9, tzinfo=SimpleTZ("Z")),
#   23.290582998483494],
#  [1.544568,
#   41.989206,
#   695.421,
#   datetime.datetime(2019, 6, 2, 9, 0, 10, tzinfo=SimpleTZ("Z")),
#   23.157708688142908],
#  [1.5445,
#   41.989234,
#   695.445,
#   datetime.datetime(2019, 6, 2, 9, 0, 11, tzinfo=SimpleTZ("Z")),
#   23.191268267723494],
#  [1.544431,
#   41.989261,
#   695.436,
#   datetime.datetime(2019, 6, 2, 9, 0, 12, tzinfo=SimpleTZ("Z")),
#   23.191230569925224],
#  [1.544363,
#   41.989289,
#   695.417,
#   datetime.datetime(2019, 6, 2, 9, 0, 13, tzinfo=SimpleTZ("Z")),
#   23.156826165261148],
#  [1.544295,
#   41.989317,
#   695.518,
#   datetime.datetime(2019, 6, 2, 9, 0, 14, tzinfo=SimpleTZ("Z")),
#   23.25686333476262],
#  [1.544227,
#   41.989346,
#   695.408,
#   datetime.datetime(2019, 6, 2, 9, 0, 15, tzinfo=SimpleTZ("Z")),
#   23.51910360608219],
#  [1.544157,
#   41.989374,
#   695.536,
#   datetime.datetime(2019, 6, 2, 9, 0, 16, tzinfo=SimpleTZ("Z")),
#   23.816881462864437],
#  [1.544086,
#   41.989402,
#   695.73,
#   datetime.datetime(2019, 6, 2, 9, 0, 17, tzinfo=SimpleTZ("Z")),
#   23.947507287281514],
#  [1.544015,
#   41.98943,
#   695.624,
#   datetime.datetime(2019, 6, 2, 9, 0, 18, tzinfo=SimpleTZ("Z")),
#   24.037983245643947],
#  [1.543944,
#   41.989459,
#   695.676,
#   datetime.datetime(2019, 6, 2, 9, 0, 19, tzinfo=SimpleTZ("Z")),
#   24.002534540444785],
#  [1.543874,
#   41.989488,
#   695.769,
#   datetime.datetime(2019, 6, 2, 9, 0, 20, tzinfo=SimpleTZ("Z")),
#   23.871895338429397],
#  [1.543804,
#   41.989517,
#   695.752,
#   datetime.datetime(2019, 6, 2, 9, 0, 21, tzinfo=SimpleTZ("Z")),
#   23.905878137846752],
#  [1.543733,
#   41.989545,
#   695.775,
#   datetime.datetime(2019, 6, 2, 9, 0, 22, tzinfo=SimpleTZ("Z")),
#   23.94147839624123],
#  [1.543662,
#   41.989573,
#   695.839,
#   datetime.datetime(2019, 6, 2, 9, 0, 23, tzinfo=SimpleTZ("Z")),
#   24.038009019640494],
#  [1.543591,
#   41.989602,
#   695.737,
#   datetime.datetime(2019, 6, 2, 9, 0, 24, tzinfo=SimpleTZ("Z")),
#   24.36014180483514],
#  [1.543519,
#   41.989632,
#   695.749,
#   datetime.datetime(2019, 6, 2, 9, 0, 25, tzinfo=SimpleTZ("Z")),
#   24.6230456350002],
#  [1.543446,
#   41.989661,
#   695.613,
#   datetime.datetime(2019, 6, 2, 9, 0, 26, tzinfo=SimpleTZ("Z")),
#   24.527486871156224],
#  [1.543374,
#   41.98969,
#   695.708,
#   datetime.datetime(2019, 6, 2, 9, 0, 27, tzinfo=SimpleTZ("Z")),
#   24.432063524487482],
#  [1.543301,
#   41.989718,
#   695.746,
#   datetime.datetime(2019, 6, 2, 9, 0, 28, tzinfo=SimpleTZ("Z")),
#   24.527841478384573],
#  [1.543229,
#   41.989748,
#   695.79,
#   datetime.datetime(2019, 6, 2, 9, 0, 29, tzinfo=SimpleTZ("Z")),
#   24.68803396330852],
#  [1.543157,
#   41.989779,
#   695.654,
#   datetime.datetime(2019, 6, 2, 9, 0, 30, tzinfo=SimpleTZ("Z")),
#   24.722319919372584],
#  [1.543084,
#   41.989808,
#   695.686,
#   datetime.datetime(2019, 6, 2, 9, 0, 31, tzinfo=SimpleTZ("Z")),
#   24.919936866750653],
#  [1.543009,
#   41.989837,
#   695.789,
#   datetime.datetime(2019, 6, 2, 9, 0, 32, tzinfo=SimpleTZ("Z")),
#   25.149643241644565],
#  [1.542935,
#   41.989867,
#   695.622,
#   datetime.datetime(2019, 6, 2, 9, 0, 33, tzinfo=SimpleTZ("Z")),
#   24.980569387062413],
#  [1.542862,
#   41.989897,
#   695.645,
#   datetime.datetime(2019, 6, 2, 9, 0, 34, tzinfo=SimpleTZ("Z")),
#   24.889373412802914],
#  [1.542788,
#   41.989926,
#   695.879,
#   datetime.datetime(2019, 6, 2, 9, 0, 35, tzinfo=SimpleTZ("Z")),
#   24.6627224229644],
#  [1.542716,
#   41.989955,
#   695.833,
#   datetime.datetime(2019, 6, 2, 9, 0, 36, tzinfo=SimpleTZ("Z")),
#   24.60872719821052],
#  [1.542641,
#   41.989982,
#   695.923,
#   datetime.datetime(2019, 6, 2, 9, 0, 37, tzinfo=SimpleTZ("Z")),
#   24.745267135371208],
#  [1.542568,
#   41.990011,
#   695.715,
#   datetime.datetime(2019, 6, 2, 9, 0, 38, tzinfo=SimpleTZ("Z")),
#   24.701075454323842],
#  [1.542494,
#   41.990039,
#   695.808,
#   datetime.datetime(2019, 6, 2, 9, 0, 39, tzinfo=SimpleTZ("Z")),
#   24.567553246606533],
#  [1.542422,
#   41.990068,
#   695.966,
#   datetime.datetime(2019, 6, 2, 9, 0, 40, tzinfo=SimpleTZ("Z")),
#   24.30586695999438],
#  [1.54235,
#   41.990096,
#   695.79,
#   datetime.datetime(2019, 6, 2, 9, 0, 41, tzinfo=SimpleTZ("Z")),
#   24.272044527752886],
#  [1.542279,
#   41.990126,
#   695.654,
#   datetime.datetime(2019, 6, 2, 9, 0, 42, tzinfo=SimpleTZ("Z")),
#   24.33109608525938],
#  [1.542208,
#   41.990156,
#   695.776,
#   datetime.datetime(2019, 6, 2, 9, 0, 43, tzinfo=SimpleTZ("Z")),
#   24.13564102626837],
#  [1.542137,
#   41.990184,
#   695.779,
#   datetime.datetime(2019, 6, 2, 9, 0, 44, tzinfo=SimpleTZ("Z")),
#   24.039189583313195],
#  [1.542066,
#   41.990213,
#   695.622,
#   datetime.datetime(2019, 6, 2, 9, 0, 45, tzinfo=SimpleTZ("Z")),
#   24.10294073071483],
#  [1.541996,
#   41.990243,
#   695.635,
#   datetime.datetime(2019, 6, 2, 9, 0, 46, tzinfo=SimpleTZ("Z")),
#   24.09964933824041],
#  [1.541925,
#   41.990272,
#   695.649,
#   datetime.datetime(2019, 6, 2, 9, 0, 47, tzinfo=SimpleTZ("Z")),
#   24.16963215782417],
#  [1.541853,
#   41.9903,
#   695.527,
#   datetime.datetime(2019, 6, 2, 9, 0, 48, tzinfo=SimpleTZ("Z")),
#   24.138347936462125],
#  [1.541783,
#   41.99033,
#   695.568,
#   datetime.datetime(2019, 6, 2, 9, 0, 49, tzinfo=SimpleTZ("Z")),
#   24.19785372207798],
#  [1.541712,
#   41.99036,
#   695.614,
#   datetime.datetime(2019, 6, 2, 9, 0, 50, tzinfo=SimpleTZ("Z")),
#   24.229099395205417],
#  [1.541641,
#   41.990389,
#   695.608,
#   datetime.datetime(2019, 6, 2, 9, 0, 51, tzinfo=SimpleTZ("Z")),
#   24.17088305354655],
#  [1.541569,
#   41.990417,
#   695.765,
#   datetime.datetime(2019, 6, 2, 9, 0, 52, tzinfo=SimpleTZ("Z")),
#   24.17267652682796],
#  [1.541498,
#   41.990446,
#   695.649,
#   datetime.datetime(2019, 6, 2, 9, 0, 53, tzinfo=SimpleTZ("Z")),
#   24.101353325392846],
#  [1.541428,
#   41.990476,
#   695.643,
#   datetime.datetime(2019, 6, 2, 9, 0, 54, tzinfo=SimpleTZ("Z")),
#   24.099603124780522],
#  [1.541357,
#   41.990505,
#   695.665,
#   datetime.datetime(2019, 6, 2, 9, 0, 55, tzinfo=SimpleTZ("Z")),
#   23.873109918030472],
#  [1.541288,
#   41.990534,
#   695.538,
#   datetime.datetime(2019, 6, 2, 9, 0, 56, tzinfo=SimpleTZ("Z")),
#   23.647921227371715],
#  [1.541218,
#   41.990562,
#   695.641,
#   datetime.datetime(2019, 6, 2, 9, 0, 57, tzinfo=SimpleTZ("Z")),
#   23.679554198195966],
#  [1.541148,
#   41.99059,
#   695.684,
#   datetime.datetime(2019, 6, 2, 9, 0, 58, tzinfo=SimpleTZ("Z")),
#   23.587817664608213],
#  [1.541078,
#   41.990617,
#   695.528,
#   datetime.datetime(2019, 6, 2, 9, 0, 59, tzinfo=SimpleTZ("Z")),
#   23.55425912222179],
#  [1.541009,
#   41.990646,
#   695.575,
#   datetime.datetime(2019, 6, 2, 9, 1, tzinfo=SimpleTZ("Z")),
#   23.74372322419896],
#  [1.540939,
#   41.990675,
#   695.428,
#   datetime.datetime(2019, 6, 2, 9, 1, 1, tzinfo=SimpleTZ("Z")),
#   23.777021260886485],
#  [1.540869,
#   41.990703,
#   695.42,
#   datetime.datetime(2019, 6, 2, 9, 1, 2, tzinfo=SimpleTZ("Z")),
#   23.677837369675917],
#  [1.540799,
#   41.990731,
#   695.408,
#   datetime.datetime(2019, 6, 2, 9, 1, 3, tzinfo=SimpleTZ("Z")),
#   23.778578605488136],
#  [1.540729,
#   41.99076,
#   695.59,
#   datetime.datetime(2019, 6, 2, 9, 1, 4, tzinfo=SimpleTZ("Z")),
#   24.006923853626727],
#  [1.540658,
#   41.990789,
#   695.474,
#   datetime.datetime(2019, 6, 2, 9, 1, 5, tzinfo=SimpleTZ("Z")),
#   24.134176169072962],
#  [1.540587,
#   41.990818,
#   695.578,
#   datetime.datetime(2019, 6, 2, 9, 1, 6, tzinfo=SimpleTZ("Z")),
#   24.00320630113853],
#  [1.540517,
#   41.990847,
#   695.67,
#   datetime.datetime(2019, 6, 2, 9, 1, 7, tzinfo=SimpleTZ("Z")),
#   23.90770115251906],
#  [1.540446,
#   41.990875,
#   695.763,
#   datetime.datetime(2019, 6, 2, 9, 1, 8, tzinfo=SimpleTZ("Z")),
#   23.854877609515967],
#  [1.540375,
#   41.990902,
#   695.556,
#   datetime.datetime(2019, 6, 2, 9, 1, 9, tzinfo=SimpleTZ("Z")),
#   23.72249684310268],
#  [1.540305,
#   41.99093,
#   695.589,
#   datetime.datetime(2019, 6, 2, 9, 1, 10, tzinfo=SimpleTZ("Z")),
#   23.5477611403144],
#  [1.540236,
#   41.990958,
#   695.513,
#   datetime.datetime(2019, 6, 2, 9, 1, 11, tzinfo=SimpleTZ("Z")),
#   23.462605476018044],
#  [1.540169,
#   41.990989,
#   695.548,
#   datetime.datetime(2019, 6, 2, 9, 1, 12, tzinfo=SimpleTZ("Z")),
#   23.61945093916168],
#  [1.540102,
#   41.991021,
#   695.361,
#   datetime.datetime(2019, 6, 2, 9, 1, 13, tzinfo=SimpleTZ("Z")),
#   23.748793657569568],
#  [1.540034,
#   41.991052,
#   695.217,
#   datetime.datetime(2019, 6, 2, 9, 1, 14, tzinfo=SimpleTZ("Z")),
#   23.738101191252486],
#  [1.539896,
#   41.991111,
#   695.208,
#   datetime.datetime(2019, 6, 2, 9, 1, 16, tzinfo=SimpleTZ("Z")),
#   23.790320123992753],
#  [1.539826,
#   41.99114,
#   695.257,
#   datetime.datetime(2019, 6, 2, 9, 1, 17, tzinfo=SimpleTZ("Z")),
#   23.945824968191992],
#  [1.539754,
#   41.991167,
#   695.271,
#   datetime.datetime(2019, 6, 2, 9, 1, 18, tzinfo=SimpleTZ("Z")),
#   24.020758867751116],
#  [1.539682,
#   41.991194,
#   695.265,
#   datetime.datetime(2019, 6, 2, 9, 1, 19, tzinfo=SimpleTZ("Z")),
#   24.124358347031595],
#  [1.539613,
#   41.991226,
#   695.157,
#   datetime.datetime(2019, 6, 2, 9, 1, 20, tzinfo=SimpleTZ("Z")),
#   23.873361300216576],
#  [1.539554,
#   41.991265,
#   695.11,
#   datetime.datetime(2019, 6, 2, 9, 1, 21, tzinfo=SimpleTZ("Z")),
#   23.186691808786865],
#  [1.53948,
#   41.991427,
#   695.283,
#   datetime.datetime(2019, 6, 2, 9, 1, 24, tzinfo=SimpleTZ("Z")),
#   22.93284912248866],
#  [1.539357,
#   41.991573,
#   695.276,
#   datetime.datetime(2019, 6, 2, 9, 1, 27, tzinfo=SimpleTZ("Z")),
#   23.80076288410533],
#  [1.539285,
#   41.991603,
#   695.14,
#   datetime.datetime(2019, 6, 2, 9, 1, 28, tzinfo=SimpleTZ("Z")),
#   24.87245914284327],
#  [1.539203,
#   41.991618,
#   695.064,
#   datetime.datetime(2019, 6, 2, 9, 1, 29, tzinfo=SimpleTZ("Z")),
#   25.38696088471635],
#  [1.539117,
#   41.991619,
#   695.006,
#   datetime.datetime(2019, 6, 2, 9, 1, 30, tzinfo=SimpleTZ("Z")),
#   25.865216103454376],
#  [1.53903,
#   41.991611,
#   695.016,
#   datetime.datetime(2019, 6, 2, 9, 1, 31, tzinfo=SimpleTZ("Z")),
#   26.112386229908097],
#  [1.538943,
#   41.991603,
#   694.908,
#   datetime.datetime(2019, 6, 2, 9, 1, 32, tzinfo=SimpleTZ("Z")),
#   26.389378459747117],
#  [1.538764,
#   41.991602,
#   694.589,
#   datetime.datetime(2019, 6, 2, 9, 1, 34, tzinfo=SimpleTZ("Z")),
#   27.009620223407353],
#  [1.538499,
#   41.991658,
#   694.393,
#   datetime.datetime(2019, 6, 2, 9, 1, 37, tzinfo=SimpleTZ("Z")),
#   27.642547834792232],
#  [1.538255,
#   41.991762,
#   693.977,
#   datetime.datetime(2019, 6, 2, 9, 1, 40, tzinfo=SimpleTZ("Z")),
#   27.979127363676838],
#  [1.53817,
#   41.991792,
#   693.939,
#   datetime.datetime(2019, 6, 2, 9, 1, 41, tzinfo=SimpleTZ("Z")),
#   27.5109398623472],
#  [1.538091,
#   41.991825,
#   693.842,
#   datetime.datetime(2019, 6, 2, 9, 1, 42, tzinfo=SimpleTZ("Z")),
#   27.333248658651154],
#  [1.538011,
#   41.99186,
#   693.535,
#   datetime.datetime(2019, 6, 2, 9, 1, 43, tzinfo=SimpleTZ("Z")),
#   27.539330586461105],
#  [1.537932,
#   41.991895,
#   693.768,
#   datetime.datetime(2019, 6, 2, 9, 1, 44, tzinfo=SimpleTZ("Z")),
#   27.366778969174092],
#  [1.537851,
#   41.991927,
#   693.632,
#   datetime.datetime(2019, 6, 2, 9, 1, 45, tzinfo=SimpleTZ("Z")),
#   27.19615946536948],
#  [1.537771,
#   41.991959,
#   693.782,
#   datetime.datetime(2019, 6, 2, 9, 1, 46, tzinfo=SimpleTZ("Z")),
#   26.929248693928038],
#  [1.53769,
#   41.991988,
#   693.543,
#   datetime.datetime(2019, 6, 2, 9, 1, 47, tzinfo=SimpleTZ("Z")),
#   26.707083696166002],
#  [1.537611,
#   41.992019,
#   693.317,
#   datetime.datetime(2019, 6, 2, 9, 1, 48, tzinfo=SimpleTZ("Z")),
#   26.67791426024445],
#  [1.537533,
#   41.992052,
#   693.408,
#   datetime.datetime(2019, 6, 2, 9, 1, 49, tzinfo=SimpleTZ("Z")),
#   26.71459385227673],
#  [1.537453,
#   41.992082,
#   693.551,
#   datetime.datetime(2019, 6, 2, 9, 1, 50, tzinfo=SimpleTZ("Z")),
#   26.561625521292008],
#  [1.537374,
#   41.992112,
#   693.695,
#   datetime.datetime(2019, 6, 2, 9, 1, 51, tzinfo=SimpleTZ("Z")),
#   26.48479552327906],
#  [1.537296,
#   41.992144,
#   693.569,
#   datetime.datetime(2019, 6, 2, 9, 1, 52, tzinfo=SimpleTZ("Z")),
#   26.349800496065388],
#  [1.537218,
#   41.992174,
#   693.571,
#   datetime.datetime(2019, 6, 2, 9, 1, 53, tzinfo=SimpleTZ("Z")),
#   26.166449509290977],
#  [1.53714,
#   41.992204,
#   693.324,
#   datetime.datetime(2019, 6, 2, 9, 1, 54, tzinfo=SimpleTZ("Z")),
#   26.07674047688478],
#  [1.537062,
#   41.992233,
#   693.227,
#   datetime.datetime(2019, 6, 2, 9, 1, 55, tzinfo=SimpleTZ("Z")),
#   26.16250593118953],
#  [1.536984,
#   41.992264,
#   693.21,
#   datetime.datetime(2019, 6, 2, 9, 1, 56, tzinfo=SimpleTZ("Z")),
#   26.351225018090055],
#  [1.536906,
#   41.992295,
#   692.994,
#   datetime.datetime(2019, 6, 2, 9, 1, 57, tzinfo=SimpleTZ("Z")),
#   26.257925912623797],
#  [1.536828,
#   41.992325,
#   692.976,
#   datetime.datetime(2019, 6, 2, 9, 1, 58, tzinfo=SimpleTZ("Z")),
#   26.291352282547347],
#  [1.536749,
#   41.992355,
#   692.99,
#   datetime.datetime(2019, 6, 2, 9, 1, 59, tzinfo=SimpleTZ("Z")),
#   26.432746683661776],
#  [1.53667,
#   41.992385,
#   692.719,
#   datetime.datetime(2019, 6, 2, 9, 2, tzinfo=SimpleTZ("Z")),
#   26.56646408078327],
#  [1.53659,
#   41.992415,
#   692.808,
#   datetime.datetime(2019, 6, 2, 9, 2, 1, tzinfo=SimpleTZ("Z")),
#   26.614378620553865],
#  [1.536512,
#   41.992447,
#   692.75,
#   datetime.datetime(2019, 6, 2, 9, 2, 2, tzinfo=SimpleTZ("Z")),
#   26.801143522390703],
#  [1.536432,
#   41.992479,
#   692.894,
#   datetime.datetime(2019, 6, 2, 9, 2, 3, tzinfo=SimpleTZ("Z")),
#   27.029680965405117],
#  [1.536353,
#   41.992512,
#   692.788,
#   datetime.datetime(2019, 6, 2, 9, 2, 4, tzinfo=SimpleTZ("Z")),
#   27.095929040825787],
#  [1.536274,
#   41.992546,
#   692.62,
#   datetime.datetime(2019, 6, 2, 9, 2, 5, tzinfo=SimpleTZ("Z")),
#   27.066731588297962],
#  [1.536196,
#   41.99258,
#   692.733,
#   datetime.datetime(2019, 6, 2, 9, 2, 6, tzinfo=SimpleTZ("Z")),
#   26.935025699228383],
#  [1.536118,
#   41.992614,
#   692.786,
#   datetime.datetime(2019, 6, 2, 9, 2, 7, tzinfo=SimpleTZ("Z")),
#   26.96324261376722],
#  [1.536039,
#   41.992647,
#   692.729,
#   datetime.datetime(2019, 6, 2, 9, 2, 8, tzinfo=SimpleTZ("Z")),
#   26.90254664992107],
#  [1.53596,
#   41.992679,
#   692.483,
#   datetime.datetime(2019, 6, 2, 9, 2, 9, tzinfo=SimpleTZ("Z")),
#   26.712051800171224],
#  [1.535881,
#   41.99271,
#   692.366,
#   datetime.datetime(2019, 6, 2, 9, 2, 10, tzinfo=SimpleTZ("Z")),
#   26.672618060234534],
#  [1.535803,
#   41.992743,
#   692.429,
#   datetime.datetime(2019, 6, 2, 9, 2, 11, tzinfo=SimpleTZ("Z")),
#   26.862709774324376],
#  [1.535724,
#   41.992776,
#   692.421,
#   datetime.datetime(2019, 6, 2, 9, 2, 12, tzinfo=SimpleTZ("Z")),
#   27.027289400593954],
#  [1.535644,
#   41.992808,
#   692.308,
#   datetime.datetime(2019, 6, 2, 9, 2, 13, tzinfo=SimpleTZ("Z")),
#   27.15870382560858],
#  [1.535564,
#   41.992841,
# ...
#   41.992666,
#   746.32,
#   datetime.datetime(2019, 6, 2, 9, 19, 34, tzinfo=SimpleTZ("Z")),
#   13.304749376631758],
#  [1.503565,
#   41.992694,
#   746.723,
#   datetime.datetime(2019, 6, 2, 9, 19, 36, tzinfo=SimpleTZ("Z")),
#   11.873163506610444],
#  [1.503501,
#   41.992713,
#   747.116,
#   datetime.datetime(2019, 6, 2, 9, 19, 38, tzinfo=SimpleTZ("Z")),
#   9.830660543695538],
#  [1.503411,
#   41.992733,
#   747.899,
#   datetime.datetime(2019, 6, 2, 9, 19, 41, tzinfo=SimpleTZ("Z")),
#   10.112464466661747],
#  [1.503339,
#   41.992741,
#   748.153,
#   datetime.datetime(2019, 6, 2, 9, 19, 43, tzinfo=SimpleTZ("Z")),
#   11.474133297390402],
#  [1.503258,
#   41.99274,
#   748.644,
#   datetime.datetime(2019, 6, 2, 9, 19, 45, tzinfo=SimpleTZ("Z")),
#   12.403972220062569],
#  [1.503174,
#   41.992729,
#   748.905,
#   datetime.datetime(2019, 6, 2, 9, 19, 47, tzinfo=SimpleTZ("Z")),
#   13.238982625956456],
#  [1.503085,
#   41.992711,
#   749.415,
#   datetime.datetime(2019, 6, 2, 9, 19, 49, tzinfo=SimpleTZ("Z")),
#   13.170819832849999],
#  [1.503005,
#   41.992691,
#   749.608,
#   datetime.datetime(2019, 6, 2, 9, 19, 51, tzinfo=SimpleTZ("Z")),
#   13.176297940039953],
#  [1.502917,
#   41.99267,
#   749.947,
#   datetime.datetime(2019, 6, 2, 9, 19, 53, tzinfo=SimpleTZ("Z")),
#   12.874688208892014],
#  [1.502842,
#   41.992649,
#   750.461,
#   datetime.datetime(2019, 6, 2, 9, 19, 55, tzinfo=SimpleTZ("Z")),
#   12.461187341583218],
#  [1.50276,
#   41.992628,
#   750.985,
#   datetime.datetime(2019, 6, 2, 9, 19, 57, tzinfo=SimpleTZ("Z")),
#   13.401940715722226],
#  [1.502672,
#   41.992606,
#   751.457,
#   datetime.datetime(2019, 6, 2, 9, 19, 59, tzinfo=SimpleTZ("Z")),
#   11.617723411674344],
#  [1.502612,
#   41.992592,
#   751.77,
#   datetime.datetime(2019, 6, 2, 9, 20, 1, tzinfo=SimpleTZ("Z")),
#   10.04513992220676],
#  [1.502544,
#   41.992575,
#   752.163,
#   datetime.datetime(2019, 6, 2, 9, 20, 3, tzinfo=SimpleTZ("Z")),
#   11.71546218667044],
#  [1.502464,
#   41.992553,
#   752.556,
#   datetime.datetime(2019, 6, 2, 9, 20, 5, tzinfo=SimpleTZ("Z")),
#   11.32167921478434],
#  [1.502402,
#   41.992535,
#   752.77,
#   datetime.datetime(2019, 6, 2, 9, 20, 7, tzinfo=SimpleTZ("Z")),
#   10.172528765600013],
#  [1.502338,
#   41.992514,
#   752.967,
#   datetime.datetime(2019, 6, 2, 9, 20, 9, tzinfo=SimpleTZ("Z")),
#   10.719463116108823],
#  [1.502266,
#   41.992502,
#   753.381,
#   datetime.datetime(2019, 6, 2, 9, 20, 11, tzinfo=SimpleTZ("Z")),
#   10.924174060968355],
#  [1.502197,
#   41.992485,
#   753.619,
#   datetime.datetime(2019, 6, 2, 9, 20, 13, tzinfo=SimpleTZ("Z")),
#   10.20556285985749],
#  [1.502137,
#   41.992468,
#   753.908,
#   datetime.datetime(2019, 6, 2, 9, 20, 15, tzinfo=SimpleTZ("Z")),
#   9.451821582918752],
#  [1.502078,
#   41.992453,
#   754.389,
#   datetime.datetime(2019, 6, 2, 9, 20, 17, tzinfo=SimpleTZ("Z")),
#   9.66513157953454],
#  [1.502014,
#   41.992438,
#   754.633,
#   datetime.datetime(2019, 6, 2, 9, 20, 19, tzinfo=SimpleTZ("Z")),
#   9.795027329691061],
#  [1.501953,
#   41.992423,
#   754.957,
#   datetime.datetime(2019, 6, 2, 9, 20, 21, tzinfo=SimpleTZ("Z")),
#   9.664651565640526],
#  [1.501891,
#   41.992408,
#   755.399,
#   datetime.datetime(2019, 6, 2, 9, 20, 23, tzinfo=SimpleTZ("Z")),
#   9.75094557454979],
#  [1.501828,
#   41.992395,
#   755.762,
#   datetime.datetime(2019, 6, 2, 9, 20, 25, tzinfo=SimpleTZ("Z")),
#   9.990680618576626],
#  [1.501761,
#   41.992384,
#   755.915,
#   datetime.datetime(2019, 6, 2, 9, 20, 27, tzinfo=SimpleTZ("Z")),
#   10.12431396345763],
#  [1.501695,
#   41.992375,
#   756.368,
#   datetime.datetime(2019, 6, 2, 9, 20, 29, tzinfo=SimpleTZ("Z")),
#   9.984087868007107],
#  [1.501629,
#   41.992368,
#   756.652,
#   datetime.datetime(2019, 6, 2, 9, 20, 31, tzinfo=SimpleTZ("Z")),
#   9.897136797251195],
#  [1.501563,
#   41.992366,
#   756.956,
#   datetime.datetime(2019, 6, 2, 9, 20, 33, tzinfo=SimpleTZ("Z")),
#   9.476639074254429],
#  [1.501502,
#   41.992366,
#   757.259,
#   datetime.datetime(2019, 6, 2, 9, 20, 35, tzinfo=SimpleTZ("Z")),
#   9.691210419592764],
#  [1.501433,
#   41.992367,
#   757.414,
#   datetime.datetime(2019, 6, 2, 9, 20, 37, tzinfo=SimpleTZ("Z")),
#   9.77056138828606],
#  [1.501371,
#   41.99237,
#   757.608,
#   datetime.datetime(2019, 6, 2, 9, 20, 39, tzinfo=SimpleTZ("Z")),
#   9.341597342902949],
#  [1.501308,
#   41.99237,
#   758.098,
#   datetime.datetime(2019, 6, 2, 9, 20, 41, tzinfo=SimpleTZ("Z")),
#   10.003485955771705],
#  [1.501237,
#   41.992368,
#   758.212,
#   datetime.datetime(2019, 6, 2, 9, 20, 43, tzinfo=SimpleTZ("Z")),
#   10.444085727838697],
#  [1.501169,
#   41.992359,
#   758.556,
#   datetime.datetime(2019, 6, 2, 9, 20, 45, tzinfo=SimpleTZ("Z")),
#   10.224396196050474],
#  [1.501104,
#   41.992344,
#   758.778,
#   datetime.datetime(2019, 6, 2, 9, 20, 47, tzinfo=SimpleTZ("Z")),
#   10.17033796018484],
#  [1.50104,
#   41.992326,
#   758.971,
#   datetime.datetime(2019, 6, 2, 9, 20, 49, tzinfo=SimpleTZ("Z")),
#   10.217504033468549],
#  [1.500978,
#   41.992304,
#   759.174,
#   datetime.datetime(2019, 6, 2, 9, 20, 51, tzinfo=SimpleTZ("Z")),
#   14.246680656973075],
#  [1.500923,
#   41.992284,
#   759.397,
#   datetime.datetime(2019, 6, 2, 9, 20, 52, tzinfo=SimpleTZ("Z")),
#   13.37383121871229],
#  [1.500847,
#   41.992255,
#   759.751,
#   datetime.datetime(2019, 6, 2, 9, 20, 55, tzinfo=SimpleTZ("Z")),
#   9.599103058832906],
#  [1.500781,
#   41.992234,
#   760.052,
#   datetime.datetime(2019, 6, 2, 9, 20, 57, tzinfo=SimpleTZ("Z")),
#   10.630118716754554],
#  [1.500715,
#   41.992215,
#   760.353,
#   datetime.datetime(2019, 6, 2, 9, 20, 59, tzinfo=SimpleTZ("Z")),
#   10.533302541249371],
#  [1.500647,
#   41.992201,
#   760.508,
#   datetime.datetime(2019, 6, 2, 9, 21, 1, tzinfo=SimpleTZ("Z")),
#   10.4610897664413],
#  [1.500578,
#   41.992194,
#   761.008,
#   datetime.datetime(2019, 6, 2, 9, 21, 3, tzinfo=SimpleTZ("Z")),
#   10.365805913862687],
#  [1.500509,
#   41.992192,
#   761.498,
#   datetime.datetime(2019, 6, 2, 9, 21, 5, tzinfo=SimpleTZ("Z")),
#   10.388497052648745],
#  [1.500439,
#   41.992195,
#   761.792,
#   datetime.datetime(2019, 6, 2, 9, 21, 7, tzinfo=SimpleTZ("Z")),
#   10.420102826838908],
#  [1.50037,
#   41.992202,
#   762.086,
#   datetime.datetime(2019, 6, 2, 9, 21, 9, tzinfo=SimpleTZ("Z")),
#   10.545634752928448],
#  [1.500299,
#   41.99221,
#   762.368,
#   datetime.datetime(2019, 6, 2, 9, 21, 11, tzinfo=SimpleTZ("Z")),
#   10.309310314730432],
#  [1.500233,
#   41.992216,
#   762.611,
#   datetime.datetime(2019, 6, 2, 9, 21, 13, tzinfo=SimpleTZ("Z")),
#   9.883770682352273],
#  [1.500167,
#   41.992218,
#   762.944,
#   datetime.datetime(2019, 6, 2, 9, 21, 15, tzinfo=SimpleTZ("Z")),
#   9.786910211233934],
#  [1.500102,
#   41.992222,
#   763.117,
#   datetime.datetime(2019, 6, 2, 9, 21, 17, tzinfo=SimpleTZ("Z")),
#   14.11625380527325],
#  [1.50004,
#   41.992225,
#   763.271,
#   datetime.datetime(2019, 6, 2, 9, 21, 18, tzinfo=SimpleTZ("Z")),
#   12.941434198735205],
#  [1.499966,
#   41.992224,
#   763.728,
#   datetime.datetime(2019, 6, 2, 9, 21, 21, tzinfo=SimpleTZ("Z")),
#   8.708949339614154],
#  [1.499899,
#   41.992219,
#   764.089,
#   datetime.datetime(2019, 6, 2, 9, 21, 23, tzinfo=SimpleTZ("Z")),
#   10.287995982609107],
#  [1.499829,
#   41.992212,
#   764.317,
#   datetime.datetime(2019, 6, 2, 9, 21, 25, tzinfo=SimpleTZ("Z")),
#   10.379375720134489],
#  [1.499762,
#   41.992201,
#   764.608,
#   datetime.datetime(2019, 6, 2, 9, 21, 27, tzinfo=SimpleTZ("Z")),
#   10.044022590697482],
#  [1.499697,
#   41.992193,
#   765.125,
#   datetime.datetime(2019, 6, 2, 9, 21, 29, tzinfo=SimpleTZ("Z")),
#   10.218361093760057],
#  [1.499629,
#   41.992178,
#   765.459,
#   datetime.datetime(2019, 6, 2, 9, 21, 31, tzinfo=SimpleTZ("Z")),
#   10.468815932180178],
#  [1.499565,
#   41.992158,
#   765.793,
#   datetime.datetime(2019, 6, 2, 9, 21, 33, tzinfo=SimpleTZ("Z")),
#   10.05407141894293],
#  [1.499506,
#   41.992137,
#   766.025,
#   datetime.datetime(2019, 6, 2, 9, 21, 35, tzinfo=SimpleTZ("Z")),
#   9.847898825320538],
#  [1.499447,
#   41.992114,
#   766.398,
#   datetime.datetime(2019, 6, 2, 9, 21, 37, tzinfo=SimpleTZ("Z")),
#   9.852958047189535],
#  [1.49939,
#   41.99209,
#   766.571,
#   datetime.datetime(2019, 6, 2, 9, 21, 39, tzinfo=SimpleTZ("Z")),
#   10.087921922521035],
#  [1.499332,
#   41.992061,
#   766.734,
#   datetime.datetime(2019, 6, 2, 9, 21, 41, tzinfo=SimpleTZ("Z")),
#   10.591271681148928],
#  [1.499274,
#   41.992029,
#   766.998,
#   datetime.datetime(2019, 6, 2, 9, 21, 43, tzinfo=SimpleTZ("Z")),
#   11.256207842090708],
#  [1.499214,
#   41.991991,
#   767.182,
#   datetime.datetime(2019, 6, 2, 9, 21, 45, tzinfo=SimpleTZ("Z")),
#   11.666469290857894],
#  [1.499162,
#   41.991948,
#   767.343,
#   datetime.datetime(2019, 6, 2, 9, 21, 47, tzinfo=SimpleTZ("Z")),
#   11.720975979829566],
#  [1.499112,
#   41.991902,
#   767.517,
#   datetime.datetime(2019, 6, 2, 9, 21, 49, tzinfo=SimpleTZ("Z")),
#   11.83195279570431],
#  [1.499061,
#   41.991857,
#   767.908,
#   datetime.datetime(2019, 6, 2, 9, 21, 51, tzinfo=SimpleTZ("Z")),
#   11.662107633948699],
#  [1.499013,
#   41.991812,
#   768.131,
#   datetime.datetime(2019, 6, 2, 9, 21, 53, tzinfo=SimpleTZ("Z")),
#   11.54076114694484],
#  [1.498968,
#   41.991765,
#   768.385,
#   datetime.datetime(2019, 6, 2, 9, 21, 55, tzinfo=SimpleTZ("Z")),
#   11.233968358681226],
#  [1.498927,
#   41.99172,
#   768.649,
#   datetime.datetime(2019, 6, 2, 9, 21, 57, tzinfo=SimpleTZ("Z")),
#   10.901506728203453],
#  [1.498884,
#   41.991676,
#   768.851,
#   datetime.datetime(2019, 6, 2, 9, 21, 59, tzinfo=SimpleTZ("Z")),
#   11.284017046611872],
#  [1.498836,
#   41.99163,
#   768.924,
#   datetime.datetime(2019, 6, 2, 9, 22, 1, tzinfo=SimpleTZ("Z")),
#   11.683239954256548],
#  [1.498783,
#   41.991587,
#   769.267,
#   datetime.datetime(2019, 6, 2, 9, 22, 3, tzinfo=SimpleTZ("Z")),
#   11.76949856366124],
#  [1.49872,
#   41.991551,
#   769.41,
#   datetime.datetime(2019, 6, 2, 9, 22, 5, tzinfo=SimpleTZ("Z")),
#   12.088928473845003],
#  [1.498647,
#   41.991522,
#   769.724,
#   datetime.datetime(2019, 6, 2, 9, 22, 7, tzinfo=SimpleTZ("Z")),
#   12.547644283244558],
#  [1.498565,
#   41.991504,
#   770.136,
#   datetime.datetime(2019, 6, 2, 9, 22, 9, tzinfo=SimpleTZ("Z")),
#   12.228377122065822],
#  [1.498487,
#   41.991497,
#   770.217,
#   datetime.datetime(2019, 6, 2, 9, 22, 11, tzinfo=SimpleTZ("Z")),
#   11.53070203652311],
#  [1.498411,
#   41.991493,
#   770.518,
#   datetime.datetime(2019, 6, 2, 9, 22, 13, tzinfo=SimpleTZ("Z")),
#   11.875719632994356],
#  [1.498328,
#   41.991489,
#   770.708,
#   datetime.datetime(2019, 6, 2, 9, 22, 15, tzinfo=SimpleTZ("Z")),
#   12.249769189231442],
#  [1.498247,
#   41.991485,
#   771.076,
#   datetime.datetime(2019, 6, 2, 9, 22, 17, tzinfo=SimpleTZ("Z")),
#   12.257044633827345],
#  [1.498164,
#   41.991481,
#   771.46,
#   datetime.datetime(2019, 6, 2, 9, 22, 19, tzinfo=SimpleTZ("Z")),
#   12.021417492866844],
#  [1.498086,
#   41.991478,
#   771.644,
#   datetime.datetime(2019, 6, 2, 9, 22, 21, tzinfo=SimpleTZ("Z")),
#   11.932914350409174],
#  [1.498004,
#   41.991477,
#   771.986,
#   datetime.datetime(2019, 6, 2, 9, 22, 23, tzinfo=SimpleTZ("Z")),
#   11.859782287069915],
#  [1.497927,
#   41.991477,
#   772.389,
#   datetime.datetime(2019, 6, 2, 9, 22, 25, tzinfo=SimpleTZ("Z")),
#   14.015746639417465],
#  [1.497816,
#   41.991479,
#   772.622,
#   datetime.datetime(2019, 6, 2, 9, 22, 27, tzinfo=SimpleTZ("Z")),
#   12.510714801416583],
#  [1.497731,
#   41.991483,
#   773.155,
#   datetime.datetime(2019, 6, 2, 9, 22, 30, tzinfo=SimpleTZ("Z")),
#   9.90725673986841],
#  [1.497656,
#   41.991492,
#   773.529,
#   datetime.datetime(2019, 6, 2, 9, 22, 32, tzinfo=SimpleTZ("Z")),
#   12.232015983058494],
#  [1.497571,
#   41.991509,
#   773.938,
#   datetime.datetime(2019, 6, 2, 9, 22, 34, tzinfo=SimpleTZ("Z")),
#   12.226695740318107],
#  [1.4975,
#   41.991529,
#   774.27,
#   datetime.datetime(2019, 6, 2, 9, 22, 36, tzinfo=SimpleTZ("Z")),
#   11.285365573249196],
#  [1.497429,
#   41.991548,
#   774.517,
#   datetime.datetime(2019, 6, 2, 9, 22, 38, tzinfo=SimpleTZ("Z")),
#   10.966223111590152],
#  [1.497362,
#   41.991567,
#   774.708,
#   datetime.datetime(2019, 6, 2, 9, 22, 40, tzinfo=SimpleTZ("Z")),
#   10.868737996026137],
#  [1.497292,
#   41.991585,
#   775.086,
#   datetime.datetime(2019, 6, 2, 9, 22, 42, tzinfo=SimpleTZ("Z")),
#   10.913981547604312],
#  [1.497223,
#   41.991601,
#   775.36,
#   datetime.datetime(2019, 6, 2, 9, 22, 44, tzinfo=SimpleTZ("Z")),
#   11.19070667542111],
#  [1.497151,
#   41.991623,
#   775.654,
#   datetime.datetime(2019, 6, 2, 9, 22, 46, tzinfo=SimpleTZ("Z")),
#   11.228262151901363],
#  [1.497084,
#   41.991644,
#   776.036,
#   datetime.datetime(2019, 6, 2, 9, 22, 48, tzinfo=SimpleTZ("Z")),
#   10.52926351099115],
#  [1.497023,
#   41.991667,
#   776.399,
#   datetime.datetime(2019, 6, 2, 9, 22, 50, tzinfo=SimpleTZ("Z")),
#   10.114549329145522],
#  [1.496965,
#   41.991692,
#   776.872,
#   datetime.datetime(2019, 6, 2, 9, 22, 52, tzinfo=SimpleTZ("Z")),
#   9.65272925195961],
#  [1.496911,
#   41.991715,
#   777.165,
#   datetime.datetime(2019, 6, 2, 9, 22, 54, tzinfo=SimpleTZ("Z")),
#   9.38827395470036],
#  [1.496857,
#   41.99174,
#   777.489,
#   datetime.datetime(2019, 6, 2, 9, 22, 56, tzinfo=SimpleTZ("Z")),
#   9.655749764883582],
#  [1.496802,
#   41.991767,
#   777.613,
#   datetime.datetime(2019, 6, 2, 9, 22, 58, tzinfo=SimpleTZ("Z")),
#   10.00047077931861],
#  [1.496746,
#   41.991796,
#   777.943,
#   datetime.datetime(2019, 6, 2, 9, 23, tzinfo=SimpleTZ("Z")),
#   10.48125811973657],
#  [1.496687,
#   41.991827,
#   778.307,
#   datetime.datetime(2019, 6, 2, 9, 23, 2, tzinfo=SimpleTZ("Z")),
#   10.426637770711459],
#  [1.49663,
#   41.991854,
#   778.508,
#   datetime.datetime(2019, 6, 2, 9, 23, 4, tzinfo=SimpleTZ("Z")),
#   10.214230185214348],
#  [1.496571,
#   41.991881,
#   778.994,
#   datetime.datetime(2019, 6, 2, 9, 23, 6, tzinfo=SimpleTZ("Z")),
#   10.331754069666914],
#  [1.496513,
#   41.991909,
#   779.218,
#   datetime.datetime(2019, 6, 2, 9, 23, 8, tzinfo=SimpleTZ("Z")),
#   10.139568685789271],
#  [1.496456,
#   41.991935,
#   779.482,
#   datetime.datetime(2019, 6, 2, 9, 23, 10, tzinfo=SimpleTZ("Z")),
#   10.042234516157281],
#  [1.496398,
#   41.991961,
#   779.884,
#   datetime.datetime(2019, 6, 2, 9, 23, 12, tzinfo=SimpleTZ("Z")),
#   10.400108564006025],
#  [1.496337,
#   41.991989,
#   780.137,
#   datetime.datetime(2019, 6, 2, 9, 23, 14, tzinfo=SimpleTZ("Z")),
#   10.13753794683061],
#  [1.496284,
#   41.992016,
#   780.47,
#   datetime.datetime(2019, 6, 2, 9, 23, 16, tzinfo=SimpleTZ("Z")),
#   9.653027924589141],
#  [1.496229,
#   41.992042,
#   780.723,
#   datetime.datetime(2019, 6, 2, 9, 23, 18, tzinfo=SimpleTZ("Z")),
#   9.88931661297233],
#  [1.496175,
#   41.992072,
#   781.077,
#   datetime.datetime(2019, 6, 2, 9, 23, 20, tzinfo=SimpleTZ("Z")),
#   9.87295305961737],
#  [1.496123,
#   41.992101,
#   781.221,
#   datetime.datetime(2019, 6, 2, 9, 23, 22, tzinfo=SimpleTZ("Z")),
#   9.650115436483206],
#  [1.49607,
#   41.992128,
#   781.741,
#   datetime.datetime(2019, 6, 2, 9, 23, 24, tzinfo=SimpleTZ("Z")),
#   10.138910169434563],
#  [1.49601,
#   41.992157,
#   781.905,
#   datetime.datetime(2019, 6, 2, 9, 23, 26, tzinfo=SimpleTZ("Z")),
#   9.895105942236576],
#  [1.495959,
#   41.992182,
#   782.308,
#   datetime.datetime(2019, 6, 2, 9, 23, 28, tzinfo=SimpleTZ("Z")),
#   9.53446118082447],
#  [1.495904,
#   41.99221,
#   782.595,
#   datetime.datetime(2019, 6, 2, 9, 23, 30, tzinfo=SimpleTZ("Z")),
#   14.661028825698668],
#  [1.495851,
#   41.992238,
#   782.789,
#   datetime.datetime(2019, 6, 2, 9, 23, 31, tzinfo=SimpleTZ("Z")),
#   13.295177454880214],
#  [1.49579,
#   41.992267,
#   783.243,
#   datetime.datetime(2019, 6, 2, 9, 23, 34, tzinfo=SimpleTZ("Z")),
#   8.822438206158525],
#  [1.495731,
#   41.992295,
#   783.495,
#   datetime.datetime(2019, 6, 2, 9, 23, 36, tzinfo=SimpleTZ("Z")),
#   14.569031926726426],
#  [1.495678,
#   41.99232,
#   783.628,
#   datetime.datetime(2019, 6, 2, 9, 23, 37, tzinfo=SimpleTZ("Z")),
#   12.761263522083096],
#  [1.49562,
#   41.992347,
#   784.111,
#   datetime.datetime(2019, 6, 2, 9, 23, 40, tzinfo=SimpleTZ("Z")),
#   8.450688099280887],
#  [1.495563,
#   41.992374,
#   784.424,
#   datetime.datetime(2019, 6, 2, 9, 23, 42, tzinfo=SimpleTZ("Z")),
#   9.744634527575972],
#  [1.495509,
#   41.992398,
#   784.888,
#   datetime.datetime(2019, 6, 2, 9, 23, 44, tzinfo=SimpleTZ("Z")),
#   9.56165846314779],
#  [1.495454,
#   41.992424,
#   785.116,
#   datetime.datetime(2019, 6, 2, 9, 23, 46, tzinfo=SimpleTZ("Z")),
#   10.013247645812774],
#  [1.495396,
#   41.992452,
#   785.376,
#   datetime.datetime(2019, 6, 2, 9, 23, 48, tzinfo=SimpleTZ("Z")),
#   10.0967746044394],
#  [1.495341,
#   41.992479,
#   786.013,
#   datetime.datetime(2019, 6, 2, 9, 23, 50, tzinfo=SimpleTZ("Z")),
#   9.758226262612736],
#  [1.495285,
#   41.992503,
#   786.208,
#   datetime.datetime(2019, 6, 2, 9, 23, 52, tzinfo=SimpleTZ("Z")),
#   9.385219386722776],
#  ...]

# %%
#Visualizing a single point (one entry in our list).

data[0]
# Out:
# [1.558717,
#  41.973759,
#  735.147,
#  datetime.datetime(2019, 6, 2, 8, 54, 33, tzinfo=SimpleTZ("Z")),
#  0.11906591740834595]

# %%
help(gpx)
# Out:
# Help on GPX in module gpxpy.gpx object:
#
# class GPX(builtins.object)
#  |  GPX() -> None
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self) -> str
#  |      Return repr(self).
#  |
#  |  add_elevation(self, delta: float) -> None
#  |      Adjusts elevation data of GPX data.
#  |
#  |      Parameters
#  |      ----------
#  |      delta : float
#  |          Elevation delta in meters to apply to GPX data
#  |
#  |  add_missing_data(self, get_data_function: Callable[[gpxpy.gpx.GPXTrackPoint], Any], add_missing_function: Callable[[List[gpxpy.gpx.GPXTrackPoint], gpxpy.gpx.GPXTrackPoint, gpxpy.gpx.GPXTrackPoint, List[float]], NoneType]) -> None
#  |
#  |  add_missing_elevations(self) -> None
#  |
#  |  add_missing_speeds(self) -> None
#  |      The missing speeds are added to a segment.
#  |
#  |      The weighted harmonic mean is used to approximate the speed at
#  |      a :obj:'~.GPXTrackPoint'.
#  |      For this to work the speed of the first and last track point in a
#  |      segment needs to be known.
#  |
#  |  add_missing_times(self) -> None
#  |
#  |  adjust_time(self, delta: datetime.timedelta, all: bool = False) -> None
#  |      Adjusts the time of all points in all of the segments of all tracks by
#  |      the specified delta.
#  |
#  |      If all=True, waypoints and routes will also be adjusted by the specified delta.
#  |
#  |      Parameters
#  |      ----------
#  |      delta : datetime.timedelta
#  |          Positive time delta will adjust times into the future
#  |          Negative time delta will adjust times into the past
#  |      all : bool
#  |          When true, also adjusts time for waypoints and routes.
#  |
#  |  clone(self) -> 'GPX'
#  |
#  |  fill_time_data_with_regular_intervals(self, start_time: Union[datetime.datetime, NoneType] = None, time_delta: Union[datetime.timedelta, NoneType] = None, end_time: Union[datetime.datetime, NoneType] = None, force: bool = True) -> None
#  |      Fills the time data for all points in the GPX file. At least two of the parameters start_time, time_delta, and
#  |      end_time have to be provided. If the three are provided, time_delta will be ignored and will be recalculated
#  |      using start_time and end_time.
#  |
#  |      The first GPX point will have a time equal to start_time. Then points are assumed to be recorded at regular
#  |      intervals time_delta.
#  |
#  |      If the GPX file currently contains time data, it will be overwritten, unless the force flag is set to False, in
#  |      which case the function will return a GPXException error.
#  |
#  |      Parameters
#  |      ----------
#  |      start_time: datetime.datetime object
#  |          Start time of the GPX file (corresponds to the time of the first point)
#  |      time_delta: datetime.timedelta object
#  |          Time interval between two points in the GPX file
#  |      end_time: datetime.datetime object
#  |          End time of the GPX file (corresponds to the time of the last point)
#  |      force: bool
#  |          Overwrite current data if the GPX file currently contains time data
#  |
#  |  get_bounds(self) -> Union[gpxpy.gpx.GPXBounds, NoneType]
#  |      Gets the latitude and longitude bounds of the GPX file.
#  |
#  |      Returns
#  |      ----------
#  |      bounds : Bounds named tuple
#  |          min_latitude : float
#  |              Minimum latitude of track in decimal degrees [-90, 90]
#  |          max_latitude : float
#  |              Maximum latitude of track in decimal degrees [-90, 90]
#  |          min_longitude : float
#  |              Minimum longitude of track in decimal degrees [-180, 180]
#  |          max_longitude : float
#  |              Maximum longitude of track in decimal degrees [-180, 180]
#  |
#  |  get_duration(self) -> Union[float, NoneType]
#  |      Calculates duration of GPX file
#  |
#  |      Returns
#  |      -------
#  |      duration: float
#  |          Duration in seconds or None if time data is not fully populated.
#  |
#  |  get_elevation_extremes(self) -> gpxpy.gpx.MinimumMaximum
#  |      Calculate elevation extremes of GPX file
#  |
#  |      Returns
#  |      -------
#  |      min_max_elevation: MinimumMaximum named tuple
#  |          minimum: float
#  |              Minimum elevation in meters
#  |          maximum: float
#  |              Maximum elevation in meters
#  |
#  |  get_location_at(self, time: datetime.datetime) -> List[gpxpy.geo.Location]
#  |      Gets approx. location at given time. Note that, at the moment this
#  |      method returns an instance of GPXTrackPoint in the future -- this may
#  |      be a mod_geo.Location instance with approximated latitude, longitude
#  |      and elevation!
#  |
#  |  get_moving_data(self, stopped_speed_threshold: Union[float, NoneType] = None) -> gpxpy.gpx.MovingData
#  |      Return a tuple of (moving_time, stopped_time, moving_distance, stopped_distance, max_speed)
#  |      that may be used for detecting the time stopped, and max speed. Not that those values are not
#  |      absolutely true, because the "stopped" or "moving" information aren't saved in the track.
#  |
#  |      Because of errors in the GPS recording, it may be good to calculate them on a reduced and
#  |      smoothed version of the track. Something like this:
#  |
#  |      cloned_gpx = gpx.clone()
#  |      cloned_gpx.reduce_points(2000, min_distance=10)
#  |      cloned_gpx.smooth(vertical=True, horizontal=True)
#  |      cloned_gpx.smooth(vertical=True, horizontal=False)
#  |      moving_time, stopped_time, moving_distance, stopped_distance, max_speed_ms = cloned_gpx.get_moving_data
#  |      max_speed_kmh = max_speed_ms * 60. ** 2 / 1000.
#  |
#  |      Experiment with your own variations to get the values you expect.
#  |
#  |      Max speed is in m/s.
#  |
#  |  get_nearest_location(self, location: gpxpy.geo.Location) -> Union[gpxpy.gpx.NearestLocationData, NoneType]
#  |      Returns (location, track_no, track_segment_no, track_point_no) for the
#  |      nearest location on map
#  |
#  |  get_nearest_locations(self, location: gpxpy.geo.Location, threshold_distance: float = 0.01) -> List[gpxpy.gpx.NearestLocationData]
#  |      Returns a list of locations of elements like
#  |      consisting of points where the location may be on the track
#  |
#  |      threshold_distance is the minimum distance from the track
#  |      so that the point *may* be counted as to be "on the track".
#  |      For example 0.01 means 1% of the track distance.
#  |
#  |  get_points_data(self, distance_2d: bool = False) -> List[gpxpy.gpx.PointData]
#  |      Returns a list of tuples containing the actual point, its distance from the start,
#  |      track_no, segment_no, and segment_point_no
#  |
#  |  get_points_no(self) -> int
#  |      Get the number of points in all segments of all track.
#  |
#  |      Returns
#  |      ----------
#  |      num_points : integer
#  |          Number of points in GPX
#  |
#  |  get_time_bounds(self) -> gpxpy.gpx.TimeBounds
#  |      Gets the time bounds (start and end) of the GPX file.
#  |
#  |      Returns
#  |      ----------
#  |      time_bounds : TimeBounds named tuple
#  |          start_time : datetime
#  |              Start time of the first segment in track
#  |          end time : datetime
#  |              End time of the last segment in track
#  |
#  |  get_track_points_no(self) -> int
#  |      Number of track points, *without* route and waypoints
#  |
#  |  get_uphill_downhill(self) -> gpxpy.gpx.UphillDownhill
#  |      Calculates the uphill and downhill elevation climbs for the gpx file.
#  |      If elevation for some points is not found those are simply ignored.
#  |
#  |      Returns
#  |      -------
#  |      uphill_downhill: UphillDownhill named tuple
#  |          uphill: float
#  |              Uphill elevation climbs in meters
#  |          downhill: float
#  |              Downhill elevation descent in meters
#  |
#  |  has_elevations(self) -> bool
#  |      See GPXTrackSegment.has_elevations())
#  |
#  |  has_times(self) -> bool
#  |      See GPXTrackSegment.has_times()
#  |
#  |  length_2d(self) -> float
#  |      Computes 2-dimensional length of the GPX file (only latitude and
#  |      longitude, no elevation). This is the sum of 2D length of all segments
#  |      in all tracks.
#  |
#  |      Returns
#  |      ----------
#  |      length : float
#  |          Length returned in meters
#  |
#  |  length_3d(self) -> float
#  |      Computes 3-dimensional length of the GPX file (latitude, longitude, and
#  |      elevation). This is the sum of 3D length of all segments in all tracks.
#  |
#  |      Returns
#  |      ----------
#  |      length : float
#  |          Length returned in meters
#  |
#  |  move(self, location_delta: gpxpy.geo.LocationDelta) -> None
#  |      Moves each point in the gpx file (routes, waypoints, tracks).
#  |
#  |      Parameters
#  |      ----------
#  |      location_delta: LocationDelta
#  |          LocationDelta to move each point
#  |
#  |  reduce_points(self, max_points_no: Union[float, NoneType] = None, min_distance: Union[float, NoneType] = None) -> None
#  |      Reduces the number of points. Points will be updated in place.
#  |
#  |      Parameters
#  |      ----------
#  |
#  |      max_points : int
#  |          The maximum number of points to include in the GPX
#  |      min_distance : float
#  |          The minimum separation in meters between points
#  |
#  |  refresh_bounds(self) -> None
#  |      Compute bounds and reload min_latitude, max_latitude, min_longitude
#  |      and max_longitude properties of this object
#  |
#  |  remove_elevation(self, tracks: bool = True, routes: bool = False, waypoints: bool = False) -> None
#  |      Removes elevation data.
#  |
#  |  remove_empty(self) -> None
#  |      Removes segments, routes
#  |
#  |  remove_time(self, all: bool = False) -> None
#  |      Removes time data of all points in all of the segments of all tracks.
#  |
#  |      If all=True, time date will also be removed from waypoints and routes.
#  |
#  |      Parameters
#  |      ----------
#  |      all : bool
#  |          When true, also removes time data for waypoints and routes.
#  |
#  |  simplify(self, max_distance: Union[float, NoneType] = None) -> None
#  |      Simplify using the Ramer-Douglas-Peucker algorithm: http://en.wikipedia.org/wiki/Ramer-Douglas-Peucker_algorithm
#  |
#  |  smooth(self, vertical: bool = True, horizontal: bool = False, remove_extremes: bool = False) -> None
#  |      See GPXTrackSegment.smooth(...)
#  |
#  |  split(self, track_no: int, track_segment_no: int, track_point_no: int) -> None
#  |      Splits one of the segments of a track in two parts. If one of the
#  |      split segments is empty it will not be added in the result. The
#  |      segments will be split in place.
#  |
#  |      Parameters
#  |      ----------
#  |      track_no : integer
#  |          The index of the track to split
#  |      track_segment_no : integer
#  |          The index of the segment to split
#  |      track_point_no : integer
#  |          The index of the track point in the segment to split
#  |
#  |  to_xml(self, version: Union[str, NoneType] = None, prettyprint: bool = True) -> str
#  |      FIXME: Note, this method will change self.version
#  |
#  |  walk(self, only_points: bool = False) -> Iterator[Any]
#  |      Generator used to iterates through points in GPX file
#  |
#  |      Parameters
#  |      ----------
#  |      only_point s: boolean
#  |          Only yield points while walking
#  |
#  |      Yields
#  |      ----------
#  |      point : GPXTrackPoint
#  |          Point in the track
#  |      track_no : integer
#  |          Index of track containint point. This is suppressed if only_points
#  |          is True.
#  |      segment_no : integer
#  |          Index of segment containint point. This is suppressed if only_points
#  |          is True.
#  |      point_no : integer
#  |          Index of point. This is suppressed if only_points is True.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  author_email
#  |
#  |  author_link
#  |
#  |  author_link_text
#  |
#  |  author_link_type
#  |
#  |  author_name
#  |
#  |  bounds
#  |
#  |  copyright_author
#  |
#  |  copyright_license
#  |
#  |  copyright_year
#  |
#  |  creator
#  |
#  |  description
#  |
#  |  extensions
#  |
#  |  keywords
#  |
#  |  link
#  |
#  |  link_text
#  |
#  |  link_type
#  |
#  |  metadata_extensions
#  |
#  |  name
#  |
#  |  nsmap
#  |
#  |  routes
#  |
#  |  schema_locations
#  |
#  |  time
#  |
#  |  tracks
#  |
#  |  version
#  |
#  |  waypoints
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  gpx_10_fields = [<gpxpy.gpxfield.GPXField object>, <gpxpy.gpxfield.GPX...
#  |
#  |  gpx_11_fields = [<gpxpy.gpxfield.GPXField object>, <gpxpy.gpxfield.GPX...

# %%
#But there's plenty of data we can extract besides each individual point. Start and end times:

gpx_start = track.get_time_bounds().start_time
gpx_start
# Out:
# datetime.datetime(2019, 6, 2, 8, 54, 33, tzinfo=SimpleTZ("Z"))

# %%
#Activity name:

gpx_name = track.name
gpx_name
# Out:
# 'Madrona'

# %%
#Distance:

gpx_distance = track.length_3d()/1000 #Converting to km.
gpx_distance
# Out:
# 51.33266117084173

# %%
#Ride duration:

gpx_duration = track.get_duration()/60 #Converting to minutes.
gpx_duration
# Out:
# 195.88333333333333

# %%
#Maximum height:

gpx_height = gpx.get_elevation_extremes().maximum
gpx_height
# Out:
# 921.008

# %%
#Total climb:

gpx_climb = track.get_uphill_downhill().uphill
gpx_climb
# Out:
# 855.4839999999991

# %%
#Average latitude and longitude:

lat = []
long = []

for i in range(len(data)):
    lat.append(data[i][0])
    long.append(data[i][1])

avg_coords = [sum(lat)/len(lat), sum(long)/len(long)]
avg_coords
# Out:
# [1.4475997135893668, 41.98444892112242]

# %% [markdown]
# ## 2.1 Creating the parser function

# %% [markdown]
# Now that we know how to access every piece of data in our parsed gpx file, let's define a function that returns a dictionary with all valuable data. It will be easy to convert the generated dictionaries into a dataframe later.

# %%
#Defining the parser function.

def parser(filename):
    file = open(filename + '.gpx', encoding='utf-8')
    gpx = gpxpy.parse(file)
    track = gpx.tracks[0]
    segment = track.segments[0]
    gpx_start = track.get_time_bounds().start_time
    return gpx_start

# %%
parser('Madrona')
# Out:
# datetime.datetime(2019, 6, 2, 8, 54, 33, tzinfo=SimpleTZ("Z"))

# %%
'''
Tasklist for tomorrow:
                        - Finish the function with try/except blocks and encoding options.
                        - Create a df with the parsed files.
                        - Make sure that missing files are kept to a minimum.
                        - COMMIT MORE OFTEN

'''
